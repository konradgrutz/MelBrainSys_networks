# %%
# produces
# Figure 5: circos plots of source and target genes
# SupplTable S10 target genes mean impact and expr. ratios per group
# SupplFigure S6 target gene candidates scatterplot ompact vs. expression

# %%
library(reshape2)
library(ggplot2)
library(circlize)
library(scales) # for alpha semi-transparency
library(parallel)
library(pheatmap)
#library(tidytext) # reorder values within each facet of ggplot
library(gridExtra)
library(xlsx)
library(readxl)
library(ggrepel)

# %%
basePath = "/data/bcu_projects/MelBrainSys_PostdocProject_Gruetzmann/publications/2022-my-MelBrainSys-paper/scripts-etc-for-publication/"
setwd(basePath)

# %%
outDirectory = paste0(basePath,"FiguresTables/")

# %%
# define met. pairs, and annotation colors 
tmp = readRDS(file = "annotation/samplePairs-annotation-colors-clusters.rds")
patient_colors = tmp$patient_colors
tissue_colors = tmp$tissue_colors
neededSamples = tmp$neededSamples
sampleMapping = tmp$sampleMapping
samplePairs = tmp$samplePairs
samplePairPerSubgroup = tmp$samplePairPerSubgroup
subgroupPerSamplePair = tmp$subgroupPerSamplePair
subgroupNames = tmp$subgroupNames
colAnnot = tmp$colAnnot
annotColors = tmp$annotColors

# %% [markdown]
# ### chromosome sizes for circos plots

# %%
chrSizes = read.csv("annotation/hg19.chrom.sizes", header = F,sep = "\t", stringsAsFactors = F, col.names = c("chr","size"))
chrSizes = chrSizes[ chrSizes$chr %in% c(paste0("chr",1:22),"chrX"),]
o = order(as.numeric(gsub("chr(.+)","\\1",chrSizes$chr)))
chrSizes = chrSizes[o,]
# Out:
# Warning message in order(as.numeric(gsub("chr(.+)", "\\1", chrSizes$chr))):
# “NAs introduced by coercion”

# %% [markdown]
# ### gene annotation

# %%
load("annotation/Homo_sapiens.GRCh37.75-chrRename-noHaplo.RData")

# %%
head(geneAnnot,2)
dim(geneAnnot)
geneAnnot = geneAnnot[ geneAnnot$V3=="gene",]
geneAnnot$gene = gsub(".*gene_name ([^;]+).*","\\1",geneAnnot$V9)
wh = which(duplicated(geneAnnot$gene))
length(wh)
dupGeneNames = sort(unique(geneAnnot$gene[wh]))
geneAnnot = geneAnnot[ -which(geneAnnot$gene %in% dupGeneNames),]
dim(geneAnnot)
rownames(geneAnnot) = geneAnnot$gene
# Out:
#   V1   V2                   V3         V4    V5    V6 V7 V8
# 1 chr1 pseudogene           gene       11869 14412 .  +  .
# 2 chr1 processed_transcript transcript 11869 14409 .  +  .
#   V9
# 1 gene_id ENSG00000223972; gene_name DDX11L1; gene_source ensembl_havana; gene_biotype pseudogene;
# 2 gene_id ENSG00000223972; transcript_id ENST00000456328; gene_name DDX11L1; gene_source ensembl_havana; gene_biotype pseudogene; transcript_name DDX11L1-002; transcript_source havana;
# [1] 2587918       9
# [1] 2023
# [1] 55638    10

# %%
geneAnnot$pos = round((geneAnnot$V5+geneAnnot$V4)/2) # gene pos = middle of start and end
geneAnnot$pos = as.integer(geneAnnot$pos)
colnames(geneAnnot)[1]="chr"
geneAnnot$chr = as.character(geneAnnot$chr)

# %%
head(geneAnnot,3)
# Out:
#            chr  V2         chr  V4    V5    V6 V7 V8
# DDX11L1    chr1 pseudogene gene 11869 14412 .  +  .
# WASH7P     chr1 pseudogene gene 14363 29806 .  -  .
# MIR1302-10 chr1 lincRNA    gene 29554 31109 .  +  .
#            V9
# DDX11L1    gene_id ENSG00000223972; gene_name DDX11L1; gene_source ensembl_havana; gene_biotype pseudogene;
# WASH7P     gene_id ENSG00000227232; gene_name WASH7P; gene_source ensembl_havana; gene_biotype pseudogene;
# MIR1302-10 gene_id ENSG00000243485; gene_name MIR1302-10; gene_source ensembl_havana; gene_biotype lincRNA;
#            gene       pos
# DDX11L1    DDX11L1    13140
# WASH7P     WASH7P     22084
# MIR1302-10 MIR1302-10 30332

# %% [markdown]
# ### altered genes per metastases pair

# %%
tmp = readRDS(file = "altered-genes-per-patient.rds")
regGenesPerPat = tmp$regGenesPerPat
upRegGenesPerPat = tmp$upRegGenesPerPat
downRegGenesPerPat= tmp$downRegGenesPerPat

# %%
sort(regGenesPerPat$P04_BSki_1)
# Out:
#  [1] "ADAM22"    "APOL6"     "ASRGL1"    "BST2"      "C11orf63"  "CAPG"
#  [7] "CEACAM1"   "CMTM8"     "CPNE8"     "DYNLT3"    "EPHX4"     "ESPN"
# [13] "FKBP5"     "GALNT10"   "GAP43"     "HIST1H2BB" "HIST1H3C"  "HIST1H4D"
# [19] "HPGD"      "IRAK3"     "IRGQ"      "KCNQ5"     "KIAA1377"  "KIF21A"
# [25] "KLHL32"    "LRRC20"    "MFSD2A"    "MICAL2"    "MSC"       "NLRP3"
# [31] "NUDT7"     "OAS2"      "OASL"      "PARK2"     "PDXP"      "PKIA"
# [37] "PRKCZ"     "RARRES3"   "RBM20"     "SAMD13"    "SAT1"      "SCNN1A"
# [43] "SGK1"      "SLC16A10"  "SLC16A7"   "SLC25A38"  "SLC39A8"   "SLC46A3"
# [49] "SP100"     "SPAG16"    "TMEM180"   "UBA7"      "XAF1"      "XKR8"
# [55] "ZNF215"    "ZNF221"    "ZNF365"    "ZNF576"    "ZNF677"

# %%
sapply(regGenesPerPat,head)
# Out:
#      P03_BLun P04_BSki_1 P08_BSof_1 P08_BSof_2 P08_BSof_3 P16_BLun
# [1,] AIM2     PRKCZ      ESPN       ESPN       MORN1      RGS2
# [2,] ZNF677   ESPN       C1orf213   C1orf213   GPR3       CPM
# [3,] CDCA7    XKR8       TEKT2      TEKT2      KCNA2      CEP112
# [4,] ELOVL6   MFSD2A     TRAF3IP3   HPCAL4     BNIPL      KLHL6
# [5,] HIST1H1B SAMD13     TSPAN32    BNIPL      LY9        MAP3K13
# [6,] TTBK1    EPHX4      FERMT3     NUAK2      PLEKHA6    ANKRD31
#      P18_BLun_1     P18_BLun_2 P39_BLun P42_BLym_1 P42_BLym_2
# [1,] PLEKHB1        METTL18    SAMD13   ISG15      CHD5
# [2,] RASAL1         PLEKHB1    EPHX4    KCNAB2     NIPAL3
# [3,] CCDC169-SOHLH2 FUT4       GNG4     DHRS3      ILDR2
# [4,] CCDC169        CRYL1      CHRM3    ECE1       PLXNA2
# [5,] SNRPN          PTGER2     SLC35G1  NIPAL3     SCCPDH
# [6,] IL32           ADSSL1     PYROXD2  LAPTM5     PRKCQ

# %%
altGenes = NULL
for(sampleName in names(regGenesPerPat)) {
    upGenes = upRegGenesPerPat[[sampleName]]; downGenes = downRegGenesPerPat[[sampleName]]
    altGenes = rbind(altGenes,
                 data.frame(samplePair = sampleName, geneAnnot[upGenes,],direction=1,y=1),
                 data.frame(samplePair = sampleName, geneAnnot[downGenes,],direction=2,y=1))
}
altGenes$pos = as.integer(altGenes$pos)
altGenes$y = as.integer(altGenes$y)    
head(altGenes,2)
# Out:
#        samplePair chr   V2             chr.1 V4        V5        V6 V7 V8
# AIM2   P03_BLun   chr1  protein_coding gene  159032274 159116886 .  -  .
# ZNF677 P03_BLun   chr19 protein_coding gene   53731577  53758151 .  -  .
#        V9
# AIM2   gene_id ENSG00000163568; gene_name AIM2; gene_source ensembl_havana; gene_biotype protein_coding;
# ZNF677 gene_id ENSG00000197928; gene_name ZNF677; gene_source ensembl_havana; gene_biotype protein_coding;
#        gene   pos       direction y
# AIM2   AIM2   159074580 1         1
# ZNF677 ZNF677  53744864 1         1

# %% [markdown]
# ### load gene annotation: TFs, oncogenes, suppressors, signaling, ...

# %%
dat = read_excel(path = "annotation/pathway-definitions.xls", sheet = 5)
# Out:
# Warning message:
# “Expecting numeric in B17246 / R17246C2: got 'X'”
# Warning message:
# “Expecting numeric in B17247 / R17247C2: got 'X'”
# Warning message:
# “Expecting numeric in B17248 / R17248C2: got 'X'”
# Warning message:
# “Expecting numeric in B17249 / R17249C2: got 'X'”
# Warning message:
# “Expecting numeric in B17250 / R17250C2: got 'X'”
# Warning message:
# “Expecting numeric in B17251 / R17251C2: got 'X'”
# Warning message:
# “Expecting numeric in B17252 / R17252C2: got 'X'”
# Warning message:
# “Expecting numeric in B17253 / R17253C2: got 'X'”
# Warning message:
# “Expecting numeric in B17254 / R17254C2: got 'X'”
# Warning message:
# “Expecting numeric in B17255 / R17255C2: got 'X'”
# Warning message:
# “Expecting numeric in B17256 / R17256C2: got 'X'”
# Warning message:
# “Expecting numeric in B17257 / R17257C2: got 'X'”
# Warning message:
# “Expecting numeric in B17258 / R17258C2: got 'X'”
# Warning message:
# “Expecting numeric in B17259 / R17259C2: got 'X'”
# Warning message:
# “Expecting numeric in B17260 / R17260C2: got 'X'”
# Warning message:
# “Expecting numeric in B17261 / R17261C2: got 'X'”
# Warning message:
# “Expecting numeric in B17262 / R17262C2: got 'X'”
# Warning message:
# “Expecting numeric in B17263 / R17263C2: got 'X'”
# Warning message:
# “Expecting numeric in B17264 / R17264C2: got 'X'”
# Warning message:
# “Expecting numeric in B17265 / R17265C2: got 'X'”
# Warning message:
# “Expecting numeric in B17266 / R17266C2: got 'X'”
# Warning message:
# “Expecting numeric in B17267 / R17267C2: got 'X'”
# Warning message:
# “Expecting numeric in B17268 / R17268C2: got 'X'”
# Warning message:
# “Expecting numeric in B17269 / R17269C2: got 'X'”
# Warning message:
# “Expecting numeric in B17270 / R17270C2: got 'X'”
# Warning message:
# “Expecting numeric in B17271 / R17271C2: got 'X'”
# Warning message:
# “Expecting numeric in B17272 / R17272C2: got 'X'”
# Warning message:
# “Expecting numeric in B17273 / R17273C2: got 'X'”
# Warning message:
# “Expecting numeric in B17274 / R17274C2: got 'X'”
# Warning message:
# “Expecting numeric in B17275 / R17275C2: got 'X'”
# Warning message:
# “Expecting numeric in B17276 / R17276C2: got 'X'”
# Warning message:
# “Expecting numeric in B17277 / R17277C2: got 'X'”
# Warning message:
# “Expecting numeric in B17278 / R17278C2: got 'X'”
# Warning message:
# “Expecting numeric in B17279 / R17279C2: got 'X'”
# Warning message:
# “Expecting numeric in B17280 / R17280C2: got 'X'”
# Warning message:
# “Expecting numeric in B17281 / R17281C2: got 'X'”
# Warning message:
# “Expecting numeric in B17282 / R17282C2: got 'X'”
# Warning message:
# “Expecting numeric in B17283 / R17283C2: got 'X'”
# Warning message:
# “Expecting numeric in B17284 / R17284C2: got 'X'”
# Warning message:
# “Expecting numeric in B17285 / R17285C2: got 'X'”
# Warning message:
# “Expecting numeric in B17286 / R17286C2: got 'X'”
# Warning message:
# “Expecting numeric in B17287 / R17287C2: got 'X'”
# Warning message:
# “Expecting numeric in B17288 / R17288C2: got 'X'”
# Warning message:
# “Expecting numeric in B17289 / R17289C2: got 'X'”
# Warning message:
# “Expecting numeric in B17290 / R17290C2: got 'X'”
# Warning message:
# “Expecting numeric in B17291 / R17291C2: got 'X'”
# Warning message:
# “Expecting numeric in B17292 / R17292C2: got 'X'”
# Warning message:
# “Expecting numeric in B17293 / R17293C2: got 'X'”
# Warning message:
# “Expecting numeric in B17294 / R17294C2: got 'X'”
# Warning message:
# “Expecting numeric in B17295 / R17295C2: got 'X'”
# Warning message:
# “Expecting numeric in B17296 / R17296C2: got 'X'”
# Warning message:
# “Expecting numeric in B17297 / R17297C2: got 'X'”
# Warning message:
# “Expecting numeric in B17298 / R17298C2: got 'X'”
# Warning message:
# “Expecting numeric in B17299 / R17299C2: got 'X'”
# Warning message:
# “Expecting numeric in B17300 / R17300C2: got 'X'”
# Warning message:
# “Expecting numeric in B17301 / R17301C2: got 'X'”
# Warning message:
# “Expecting numeric in B17302 / R17302C2: got 'X'”
# Warning message:
# “Expecting numeric in B17303 / R17303C2: got 'X'”
# Warning message:
# “Expecting numeric in B17304 / R17304C2: got 'X'”
# Warning message:
# “Expecting numeric in B17305 / R17305C2: got 'X'”
# Warning message:
# “Expecting numeric in B17306 / R17306C2: got 'X'”
# Warning message:
# “Expecting numeric in B17307 / R17307C2: got 'X'”
# Warning message:
# “Expecting numeric in B17308 / R17308C2: got 'X'”
# Warning message:
# “Expecting numeric in B17309 / R17309C2: got 'X'”
# Warning message:
# “Expecting numeric in B17310 / R17310C2: got 'X'”
# Warning message:
# “Expecting numeric in B17311 / R17311C2: got 'X'”
# Warning message:
# “Expecting numeric in B17312 / R17312C2: got 'X'”
# Warning message:
# “Expecting numeric in B17313 / R17313C2: got 'X'”
# Warning message:
# “Expecting numeric in B17314 / R17314C2: got 'X'”
# Warning message:
# “Expecting numeric in B17315 / R17315C2: got 'X'”
# Warning message:
# “Expecting numeric in B17316 / R17316C2: got 'X'”
# Warning message:
# “Expecting numeric in B17317 / R17317C2: got 'X'”
# Warning message:
# “Expecting numeric in B17318 / R17318C2: got 'X'”
# Warning message:
# “Expecting numeric in B17319 / R17319C2: got 'X'”
# Warning message:
# “Expecting numeric in B17320 / R17320C2: got 'X'”
# Warning message:
# “Expecting numeric in B17321 / R17321C2: got 'X'”
# Warning message:
# “Expecting numeric in B17322 / R17322C2: got 'X'”
# Warning message:
# “Expecting numeric in B17323 / R17323C2: got 'X'”
# Warning message:
# “Expecting numeric in B17324 / R17324C2: got 'X'”
# Warning message:
# “Expecting numeric in B17325 / R17325C2: got 'X'”
# Warning message:
# “Expecting numeric in B17326 / R17326C2: got 'X'”
# Warning message:
# “Expecting numeric in B17327 / R17327C2: got 'X'”
# Warning message:
# “Expecting numeric in B17328 / R17328C2: got 'X'”
# Warning message:
# “Expecting numeric in B17329 / R17329C2: got 'X'”
# Warning message:
# “Expecting numeric in B17330 / R17330C2: got 'X'”
# Warning message:
# “Expecting numeric in B17331 / R17331C2: got 'X'”
# Warning message:
# “Expecting numeric in B17332 / R17332C2: got 'X'”
# Warning message:
# “Expecting numeric in B17333 / R17333C2: got 'X'”
# Warning message:
# “Expecting numeric in B17334 / R17334C2: got 'X'”
# Warning message:
# “Expecting numeric in B17335 / R17335C2: got 'X'”
# Warning message:
# “Expecting numeric in B17336 / R17336C2: got 'X'”
# Warning message:
# “Expecting numeric in B17337 / R17337C2: got 'X'”
# Warning message:
# “Expecting numeric in B17338 / R17338C2: got 'X'”
# Warning message:
# “Expecting numeric in B17339 / R17339C2: got 'X'”
# Warning message:
# “Expecting numeric in B17340 / R17340C2: got 'X'”
# Warning message:
# “Expecting numeric in B17341 / R17341C2: got 'X'”
# Warning message:
# “Expecting numeric in B17342 / R17342C2: got 'X'”
# Warning message:
# “Expecting numeric in B17343 / R17343C2: got 'X'”
# Warning message:
# “Expecting numeric in B17344 / R17344C2: got 'X'”
# Warning message:
# “Expecting numeric in B17345 / R17345C2: got 'X'”
# Warning message:
# “Expecting numeric in B17346 / R17346C2: got 'X'”
# Warning message:
# “Expecting numeric in B17347 / R17347C2: got 'X'”
# Warning message:
# “Expecting numeric in B17348 / R17348C2: got 'X'”
# Warning message:
# “Expecting numeric in B17349 / R17349C2: got 'X'”
# Warning message:
# “Expecting numeric in B17350 / R17350C2: got 'X'”
# Warning message:
# “Expecting numeric in B17351 / R17351C2: got 'X'”
# Warning message:
# “Expecting numeric in B17352 / R17352C2: got 'X'”
# Warning message:
# “Expecting numeric in B17353 / R17353C2: got 'X'”
# Warning message:
# “Expecting numeric in B17354 / R17354C2: got 'X'”
# Warning message:
# “Expecting numeric in B17355 / R17355C2: got 'X'”
# Warning message:
# “Expecting numeric in B17356 / R17356C2: got 'X'”
# Warning message:
# “Expecting numeric in B17357 / R17357C2: got 'X'”
# Warning message:
# “Expecting numeric in B17358 / R17358C2: got 'X'”
# Warning message:
# “Expecting numeric in B17359 / R17359C2: got 'X'”
# Warning message:
# “Expecting numeric in B17360 / R17360C2: got 'X'”
# Warning message:
# “Expecting numeric in B17361 / R17361C2: got 'X'”
# Warning message:
# “Expecting numeric in B17362 / R17362C2: got 'X'”
# Warning message:
# “Expecting numeric in B17363 / R17363C2: got 'X'”
# Warning message:
# “Expecting numeric in B17364 / R17364C2: got 'X'”
# Warning message:
# “Expecting numeric in B17365 / R17365C2: got 'X'”
# Warning message:
# “Expecting numeric in B17366 / R17366C2: got 'X'”
# Warning message:
# “Expecting numeric in B17367 / R17367C2: got 'X'”
# Warning message:
# “Expecting numeric in B17368 / R17368C2: got 'X'”
# Warning message:
# “Expecting numeric in B17369 / R17369C2: got 'X'”
# Warning message:
# “Expecting numeric in B17370 / R17370C2: got 'X'”
# Warning message:
# “Expecting numeric in B17371 / R17371C2: got 'X'”
# Warning message:
# “Expecting numeric in B17372 / R17372C2: got 'X'”
# Warning message:
# “Expecting numeric in B17373 / R17373C2: got 'X'”
# Warning message:
# “Expecting numeric in B17374 / R17374C2: got 'X'”
# Warning message:
# “Expecting numeric in B17375 / R17375C2: got 'X'”
# Warning message:
# “Expecting numeric in B17376 / R17376C2: got 'X'”
# Warning message:
# “Expecting numeric in B17377 / R17377C2: got 'X'”
# Warning message:
# “Expecting numeric in B17378 / R17378C2: got 'X'”
# Warning message:
# “Expecting numeric in B17379 / R17379C2: got 'X'”
# Warning message:
# “Expecting numeric in B17380 / R17380C2: got 'X'”
# Warning message:
# “Expecting numeric in B17381 / R17381C2: got 'X'”
# Warning message:
# “Expecting numeric in B17382 / R17382C2: got 'X'”
# Warning message:
# “Expecting numeric in B17383 / R17383C2: got 'X'”
# Warning message:
# “Expecting numeric in B17384 / R17384C2: got 'X'”
# Warning message:
# “Expecting numeric in B17385 / R17385C2: got 'X'”
# Warning message:
# “Expecting numeric in B17386 / R17386C2: got 'X'”
# Warning message:
# “Expecting numeric in B17387 / R17387C2: got 'X'”
# Warning message:
# “Expecting numeric in B17388 / R17388C2: got 'X'”
# Warning message:
# “Expecting numeric in B17389 / R17389C2: got 'X'”
# Warning message:
# “Expecting numeric in B17390 / R17390C2: got 'X'”
# Warning message:
# “Expecting numeric in B17391 / R17391C2: got 'X'”
# Warning message:
# “Expecting numeric in B17392 / R17392C2: got 'X'”
# Warning message:
# “Expecting numeric in B17393 / R17393C2: got 'X'”
# Warning message:
# “Expecting numeric in B17394 / R17394C2: got 'X'”
# Warning message:
# “Expecting numeric in B17395 / R17395C2: got 'X'”
# Warning message:
# “Expecting numeric in B17396 / R17396C2: got 'X'”
# Warning message:
# “Expecting numeric in B17397 / R17397C2: got 'X'”
# Warning message:
# “Expecting numeric in B17398 / R17398C2: got 'X'”
# Warning message:
# “Expecting numeric in B17399 / R17399C2: got 'X'”
# Warning message:
# “Expecting numeric in B17400 / R17400C2: got 'X'”
# Warning message:
# “Expecting numeric in B17401 / R17401C2: got 'X'”
# Warning message:
# “Expecting numeric in B17402 / R17402C2: got 'X'”
# Warning message:
# “Expecting numeric in B17403 / R17403C2: got 'X'”
# Warning message:
# “Expecting numeric in B17404 / R17404C2: got 'X'”
# Warning message:
# “Expecting numeric in B17405 / R17405C2: got 'X'”
# Warning message:
# “Expecting numeric in B17406 / R17406C2: got 'X'”
# Warning message:
# “Expecting numeric in B17407 / R17407C2: got 'X'”
# Warning message:
# “Expecting numeric in B17408 / R17408C2: got 'X'”
# Warning message:
# “Expecting numeric in B17409 / R17409C2: got 'X'”
# Warning message:
# “Expecting numeric in B17410 / R17410C2: got 'X'”
# Warning message:
# “Expecting numeric in B17411 / R17411C2: got 'X'”
# Warning message:
# “Expecting numeric in B17412 / R17412C2: got 'X'”
# Warning message:
# “Expecting numeric in B17413 / R17413C2: got 'X'”
# Warning message:
# “Expecting numeric in B17414 / R17414C2: got 'X'”
# Warning message:
# “Expecting numeric in B17415 / R17415C2: got 'X'”
# Warning message:
# “Expecting numeric in B17416 / R17416C2: got 'X'”
# Warning message:
# “Expecting numeric in B17417 / R17417C2: got 'X'”
# Warning message:
# “Expecting numeric in B17418 / R17418C2: got 'X'”
# Warning message:
# “Expecting numeric in B17419 / R17419C2: got 'X'”
# Warning message:
# “Expecting numeric in B17420 / R17420C2: got 'X'”
# Warning message:
# “Expecting numeric in B17421 / R17421C2: got 'X'”
# Warning message:
# “Expecting numeric in B17422 / R17422C2: got 'X'”
# Warning message:
# “Expecting numeric in B17423 / R17423C2: got 'X'”
# Warning message:
# “Expecting numeric in B17424 / R17424C2: got 'X'”
# Warning message:
# “Expecting numeric in B17425 / R17425C2: got 'X'”
# Warning message:
# “Expecting numeric in B17426 / R17426C2: got 'X'”
# Warning message:
# “Expecting numeric in B17427 / R17427C2: got 'X'”
# Warning message:
# “Expecting numeric in B17428 / R17428C2: got 'X'”
# Warning message:
# “Expecting numeric in B17429 / R17429C2: got 'X'”
# Warning message:
# “Expecting numeric in B17430 / R17430C2: got 'X'”
# Warning message:
# “Expecting numeric in B17431 / R17431C2: got 'X'”
# Warning message:
# “Expecting numeric in B17432 / R17432C2: got 'X'”
# Warning message:
# “Expecting numeric in B17433 / R17433C2: got 'X'”
# Warning message:
# “Expecting numeric in B17434 / R17434C2: got 'X'”
# Warning message:
# “Expecting numeric in B17435 / R17435C2: got 'X'”
# Warning message:
# “Expecting numeric in B17436 / R17436C2: got 'X'”
# Warning message:
# “Expecting numeric in B17437 / R17437C2: got 'X'”
# Warning message:
# “Expecting numeric in B17438 / R17438C2: got 'X'”
# Warning message:
# “Expecting numeric in B17439 / R17439C2: got 'X'”
# Warning message:
# “Expecting numeric in B17440 / R17440C2: got 'X'”
# Warning message:
# “Expecting numeric in B17441 / R17441C2: got 'X'”
# Warning message:
# “Expecting numeric in B17442 / R17442C2: got 'X'”
# Warning message:
# “Expecting numeric in B17443 / R17443C2: got 'X'”
# Warning message:
# “Expecting numeric in B17444 / R17444C2: got 'X'”
# Warning message:
# “Expecting numeric in B17445 / R17445C2: got 'X'”
# Warning message:
# “Expecting numeric in B17446 / R17446C2: got 'X'”
# Warning message:
# “Expecting numeric in B17447 / R17447C2: got 'X'”
# Warning message:
# “Expecting numeric in B17448 / R17448C2: got 'X'”
# Warning message:
# “Expecting numeric in B17449 / R17449C2: got 'X'”
# Warning message:
# “Expecting numeric in B17450 / R17450C2: got 'X'”
# Warning message:
# “Expecting numeric in B17451 / R17451C2: got 'X'”
# Warning message:
# “Expecting numeric in B17452 / R17452C2: got 'X'”
# Warning message:
# “Expecting numeric in B17453 / R17453C2: got 'X'”
# Warning message:
# “Expecting numeric in B17454 / R17454C2: got 'X'”
# Warning message:
# “Expecting numeric in B17455 / R17455C2: got 'X'”
# Warning message:
# “Expecting numeric in B17456 / R17456C2: got 'X'”
# Warning message:
# “Expecting numeric in B17457 / R17457C2: got 'X'”
# Warning message:
# “Expecting numeric in B17458 / R17458C2: got 'X'”
# Warning message:
# “Expecting numeric in B17459 / R17459C2: got 'X'”
# Warning message:
# “Expecting numeric in B17460 / R17460C2: got 'X'”
# Warning message:
# “Expecting numeric in B17461 / R17461C2: got 'X'”
# Warning message:
# “Expecting numeric in B17462 / R17462C2: got 'X'”
# Warning message:
# “Expecting numeric in B17463 / R17463C2: got 'X'”
# Warning message:
# “Expecting numeric in B17464 / R17464C2: got 'X'”
# Warning message:
# “Expecting numeric in B17465 / R17465C2: got 'X'”
# Warning message:
# “Expecting numeric in B17466 / R17466C2: got 'X'”
# Warning message:
# “Expecting numeric in B17467 / R17467C2: got 'X'”
# Warning message:
# “Expecting numeric in B17468 / R17468C2: got 'X'”
# Warning message:
# “Expecting numeric in B17469 / R17469C2: got 'X'”
# Warning message:
# “Expecting numeric in B17470 / R17470C2: got 'X'”
# Warning message:
# “Expecting numeric in B17471 / R17471C2: got 'X'”
# Warning message:
# “Expecting numeric in B17472 / R17472C2: got 'X'”
# Warning message:
# “Expecting numeric in B17473 / R17473C2: got 'X'”
# Warning message:
# “Expecting numeric in B17474 / R17474C2: got 'X'”
# Warning message:
# “Expecting numeric in B17475 / R17475C2: got 'X'”
# Warning message:
# “Expecting numeric in B17476 / R17476C2: got 'X'”
# Warning message:
# “Expecting numeric in B17477 / R17477C2: got 'X'”
# Warning message:
# “Expecting numeric in B17478 / R17478C2: got 'X'”
# Warning message:
# “Expecting numeric in B17479 / R17479C2: got 'X'”
# Warning message:
# “Expecting numeric in B17480 / R17480C2: got 'X'”
# Warning message:
# “Expecting numeric in B17481 / R17481C2: got 'X'”
# Warning message:
# “Expecting numeric in B17482 / R17482C2: got 'X'”
# Warning message:
# “Expecting numeric in B17483 / R17483C2: got 'X'”
# Warning message:
# “Expecting numeric in B17484 / R17484C2: got 'X'”
# Warning message:
# “Expecting numeric in B17485 / R17485C2: got 'X'”
# Warning message:
# “Expecting numeric in B17486 / R17486C2: got 'X'”
# Warning message:
# “Expecting numeric in B17487 / R17487C2: got 'X'”
# Warning message:
# “Expecting numeric in B17488 / R17488C2: got 'X'”
# Warning message:
# “Expecting numeric in B17489 / R17489C2: got 'X'”
# Warning message:
# “Expecting numeric in B17490 / R17490C2: got 'X'”
# Warning message:
# “Expecting numeric in B17491 / R17491C2: got 'X'”
# Warning message:
# “Expecting numeric in B17492 / R17492C2: got 'X'”
# Warning message:
# “Expecting numeric in B17493 / R17493C2: got 'X'”
# Warning message:
# “Expecting numeric in B17494 / R17494C2: got 'X'”
# Warning message:
# “Expecting numeric in B17495 / R17495C2: got 'X'”
# Warning message:
# “Expecting numeric in B17496 / R17496C2: got 'X'”
# Warning message:
# “Expecting numeric in B17497 / R17497C2: got 'X'”
# Warning message:
# “Expecting numeric in B17498 / R17498C2: got 'X'”
# Warning message:
# “Expecting numeric in B17499 / R17499C2: got 'X'”
# Warning message:
# “Expecting numeric in B17500 / R17500C2: got 'X'”
# Warning message:
# “Expecting numeric in B17501 / R17501C2: got 'X'”
# Warning message:
# “Expecting numeric in B17502 / R17502C2: got 'X'”
# Warning message:
# “Expecting numeric in B17503 / R17503C2: got 'X'”
# Warning message:
# “Expecting numeric in B17504 / R17504C2: got 'X'”
# Warning message:
# “Expecting numeric in B17505 / R17505C2: got 'X'”
# Warning message:
# “Expecting numeric in B17506 / R17506C2: got 'X'”
# Warning message:
# “Expecting numeric in B17507 / R17507C2: got 'X'”
# Warning message:
# “Expecting numeric in B17508 / R17508C2: got 'X'”
# Warning message:
# “Expecting numeric in B17509 / R17509C2: got 'X'”
# Warning message:
# “Expecting numeric in B17510 / R17510C2: got 'X'”
# Warning message:
# “Expecting numeric in B17511 / R17511C2: got 'X'”
# Warning message:
# “Expecting numeric in B17512 / R17512C2: got 'X'”
# Warning message:
# “Expecting numeric in B17513 / R17513C2: got 'X'”
# Warning message:
# “Expecting numeric in B17514 / R17514C2: got 'X'”
# Warning message:
# “Expecting numeric in B17515 / R17515C2: got 'X'”
# Warning message:
# “Expecting numeric in B17516 / R17516C2: got 'X'”
# Warning message:
# “Expecting numeric in B17517 / R17517C2: got 'X'”
# Warning message:
# “Expecting numeric in B17518 / R17518C2: got 'X'”
# Warning message:
# “Expecting numeric in B17519 / R17519C2: got 'X'”
# Warning message:
# “Expecting numeric in B17520 / R17520C2: got 'X'”
# Warning message:
# “Expecting numeric in B17521 / R17521C2: got 'X'”
# Warning message:
# “Expecting numeric in B17522 / R17522C2: got 'X'”
# Warning message:
# “Expecting numeric in B17523 / R17523C2: got 'X'”
# Warning message:
# “Expecting numeric in B17524 / R17524C2: got 'X'”
# Warning message:
# “Expecting numeric in B17525 / R17525C2: got 'X'”
# Warning message:
# “Expecting numeric in B17526 / R17526C2: got 'X'”
# Warning message:
# “Expecting numeric in B17527 / R17527C2: got 'X'”
# Warning message:
# “Expecting numeric in B17528 / R17528C2: got 'X'”
# Warning message:
# “Expecting numeric in B17529 / R17529C2: got 'X'”
# Warning message:
# “Expecting numeric in B17530 / R17530C2: got 'X'”
# Warning message:
# “Expecting numeric in B17531 / R17531C2: got 'X'”
# Warning message:
# “Expecting numeric in B17532 / R17532C2: got 'X'”
# Warning message:
# “Expecting numeric in B17533 / R17533C2: got 'X'”
# Warning message:
# “Expecting numeric in B17534 / R17534C2: got 'X'”
# Warning message:
# “Expecting numeric in B17535 / R17535C2: got 'X'”
# Warning message:
# “Expecting numeric in B17536 / R17536C2: got 'X'”
# Warning message:
# “Expecting numeric in B17537 / R17537C2: got 'X'”
# Warning message:
# “Expecting numeric in B17538 / R17538C2: got 'X'”
# Warning message:
# “Expecting numeric in B17539 / R17539C2: got 'X'”
# Warning message:
# “Expecting numeric in B17540 / R17540C2: got 'X'”
# Warning message:
# “Expecting numeric in B17541 / R17541C2: got 'X'”
# Warning message:
# “Expecting numeric in B17542 / R17542C2: got 'X'”
# Warning message:
# “Expecting numeric in B17543 / R17543C2: got 'X'”
# Warning message:
# “Expecting numeric in B17544 / R17544C2: got 'X'”
# Warning message:
# “Expecting numeric in B17545 / R17545C2: got 'X'”
# Warning message:
# “Expecting numeric in B17546 / R17546C2: got 'X'”
# Warning message:
# “Expecting numeric in B17547 / R17547C2: got 'X'”
# Warning message:
# “Expecting numeric in B17548 / R17548C2: got 'X'”
# Warning message:
# “Expecting numeric in B17549 / R17549C2: got 'X'”
# Warning message:
# “Expecting numeric in B17550 / R17550C2: got 'X'”
# Warning message:
# “Expecting numeric in B17551 / R17551C2: got 'X'”
# Warning message:
# “Expecting numeric in B17552 / R17552C2: got 'X'”
# Warning message:
# “Expecting numeric in B17553 / R17553C2: got 'X'”
# Warning message:
# “Expecting numeric in B17554 / R17554C2: got 'X'”
# Warning message:
# “Expecting numeric in B17555 / R17555C2: got 'X'”
# Warning message:
# “Expecting numeric in B17556 / R17556C2: got 'X'”
# Warning message:
# “Expecting numeric in B17557 / R17557C2: got 'X'”
# Warning message:
# “Expecting numeric in B17558 / R17558C2: got 'X'”
# Warning message:
# “Expecting numeric in B17559 / R17559C2: got 'X'”
# Warning message:
# “Expecting numeric in B17560 / R17560C2: got 'X'”
# Warning message:
# “Expecting numeric in B17561 / R17561C2: got 'X'”
# Warning message:
# “Expecting numeric in B17562 / R17562C2: got 'X'”
# Warning message:
# “Expecting numeric in B17563 / R17563C2: got 'X'”
# Warning message:
# “Expecting numeric in B17564 / R17564C2: got 'X'”
# Warning message:
# “Expecting numeric in B17565 / R17565C2: got 'X'”
# Warning message:
# “Expecting numeric in B17566 / R17566C2: got 'X'”
# Warning message:
# “Expecting numeric in B17567 / R17567C2: got 'X'”
# Warning message:
# “Expecting numeric in B17568 / R17568C2: got 'X'”
# Warning message:
# “Expecting numeric in B17569 / R17569C2: got 'X'”
# Warning message:
# “Expecting numeric in B17570 / R17570C2: got 'X'”
# Warning message:
# “Expecting numeric in B17571 / R17571C2: got 'X'”
# Warning message:
# “Expecting numeric in B17572 / R17572C2: got 'X'”
# Warning message:
# “Expecting numeric in B17573 / R17573C2: got 'X'”
# Warning message:
# “Expecting numeric in B17574 / R17574C2: got 'X'”
# Warning message:
# “Expecting numeric in B17575 / R17575C2: got 'X'”
# Warning message:
# “Expecting numeric in B17576 / R17576C2: got 'X'”
# Warning message:
# “Expecting numeric in B17577 / R17577C2: got 'X'”
# Warning message:
# “Expecting numeric in B17578 / R17578C2: got 'X'”
# Warning message:
# “Expecting numeric in B17579 / R17579C2: got 'X'”
# Warning message:
# “Expecting numeric in B17580 / R17580C2: got 'X'”
# Warning message:
# “Expecting numeric in B17581 / R17581C2: got 'X'”
# Warning message:
# “Expecting numeric in B17582 / R17582C2: got 'X'”
# Warning message:
# “Expecting numeric in B17583 / R17583C2: got 'X'”
# Warning message:
# “Expecting numeric in B17584 / R17584C2: got 'X'”
# Warning message:
# “Expecting numeric in B17585 / R17585C2: got 'X'”
# Warning message:
# “Expecting numeric in B17586 / R17586C2: got 'X'”
# Warning message:
# “Expecting numeric in B17587 / R17587C2: got 'X'”
# Warning message:
# “Expecting numeric in B17588 / R17588C2: got 'X'”
# Warning message:
# “Expecting numeric in B17589 / R17589C2: got 'X'”
# Warning message:
# “Expecting numeric in B17590 / R17590C2: got 'X'”
# Warning message:
# “Expecting numeric in B17591 / R17591C2: got 'X'”
# Warning message:
# “Expecting numeric in B17592 / R17592C2: got 'X'”
# Warning message:
# “Expecting numeric in B17593 / R17593C2: got 'X'”
# Warning message:
# “Expecting numeric in B17594 / R17594C2: got 'X'”
# Warning message:
# “Expecting numeric in B17595 / R17595C2: got 'X'”
# Warning message:
# “Expecting numeric in B17596 / R17596C2: got 'X'”
# Warning message:
# “Expecting numeric in B17597 / R17597C2: got 'X'”
# Warning message:
# “Expecting numeric in B17598 / R17598C2: got 'X'”
# Warning message:
# “Expecting numeric in B17599 / R17599C2: got 'X'”
# Warning message:
# “Expecting numeric in B17600 / R17600C2: got 'X'”
# Warning message:
# “Expecting numeric in B17601 / R17601C2: got 'X'”
# Warning message:
# “Expecting numeric in B17602 / R17602C2: got 'X'”
# Warning message:
# “Expecting numeric in B17603 / R17603C2: got 'X'”
# Warning message:
# “Expecting numeric in B17604 / R17604C2: got 'X'”
# Warning message:
# “Expecting numeric in B17605 / R17605C2: got 'X'”
# Warning message:
# “Expecting numeric in B17606 / R17606C2: got 'X'”
# Warning message:
# “Expecting numeric in B17607 / R17607C2: got 'X'”
# Warning message:
# “Expecting numeric in B17608 / R17608C2: got 'X'”
# Warning message:
# “Expecting numeric in B17609 / R17609C2: got 'X'”
# Warning message:
# “Expecting numeric in B17610 / R17610C2: got 'X'”
# Warning message:
# “Expecting numeric in B17611 / R17611C2: got 'X'”
# Warning message:
# “Expecting numeric in B17612 / R17612C2: got 'X'”
# Warning message:
# “Expecting numeric in B17613 / R17613C2: got 'X'”
# Warning message:
# “Expecting numeric in B17614 / R17614C2: got 'X'”
# Warning message:
# “Expecting numeric in B17615 / R17615C2: got 'X'”
# Warning message:
# “Expecting numeric in B17616 / R17616C2: got 'X'”
# Warning message:
# “Expecting numeric in B17617 / R17617C2: got 'X'”
# Warning message:
# “Expecting numeric in B17618 / R17618C2: got 'X'”
# Warning message:
# “Expecting numeric in B17619 / R17619C2: got 'X'”
# Warning message:
# “Expecting numeric in B17620 / R17620C2: got 'X'”
# Warning message:
# “Expecting numeric in B17621 / R17621C2: got 'X'”
# Warning message:
# “Expecting numeric in B17622 / R17622C2: got 'X'”
# Warning message:
# “Expecting numeric in B17623 / R17623C2: got 'X'”
# Warning message:
# “Expecting numeric in B17624 / R17624C2: got 'X'”
# Warning message:
# “Expecting numeric in B17625 / R17625C2: got 'X'”
# Warning message:
# “Expecting numeric in B17626 / R17626C2: got 'X'”
# Warning message:
# “Expecting numeric in B17627 / R17627C2: got 'X'”
# Warning message:
# “Expecting numeric in B17628 / R17628C2: got 'X'”
# Warning message:
# “Expecting numeric in B17629 / R17629C2: got 'X'”
# Warning message:
# “Expecting numeric in B17630 / R17630C2: got 'X'”
# Warning message:
# “Expecting numeric in B17631 / R17631C2: got 'X'”
# Warning message:
# “Expecting numeric in B17632 / R17632C2: got 'X'”
# Warning message:
# “Expecting numeric in B17633 / R17633C2: got 'X'”
# Warning message:
# “Expecting numeric in B17634 / R17634C2: got 'X'”
# Warning message:
# “Expecting numeric in B17635 / R17635C2: got 'X'”
# Warning message:
# “Expecting numeric in B17636 / R17636C2: got 'X'”
# Warning message:
# “Expecting numeric in B17637 / R17637C2: got 'X'”
# Warning message:
# “Expecting numeric in B17638 / R17638C2: got 'X'”
# Warning message:
# “Expecting numeric in B17639 / R17639C2: got 'X'”
# Warning message:
# “Expecting numeric in B17640 / R17640C2: got 'X'”
# Warning message:
# “Expecting numeric in B17641 / R17641C2: got 'X'”
# Warning message:
# “Expecting numeric in B17642 / R17642C2: got 'X'”
# Warning message:
# “Expecting numeric in B17643 / R17643C2: got 'X'”
# Warning message:
# “Expecting numeric in B17644 / R17644C2: got 'X'”
# Warning message:
# “Expecting numeric in B17645 / R17645C2: got 'X'”
# Warning message:
# “Expecting numeric in B17646 / R17646C2: got 'X'”
# Warning message:
# “Expecting numeric in B17647 / R17647C2: got 'X'”
# Warning message:
# “Expecting numeric in B17648 / R17648C2: got 'X'”
# Warning message:
# “Expecting numeric in B17649 / R17649C2: got 'X'”
# Warning message:
# “Expecting numeric in B17650 / R17650C2: got 'X'”
# Warning message:
# “Expecting numeric in B17651 / R17651C2: got 'X'”
# Warning message:
# “Expecting numeric in B17652 / R17652C2: got 'X'”
# Warning message:
# “Expecting numeric in B17653 / R17653C2: got 'X'”
# Warning message:
# “Expecting numeric in B17654 / R17654C2: got 'X'”
# Warning message:
# “Expecting numeric in B17655 / R17655C2: got 'X'”
# Warning message:
# “Expecting numeric in B17656 / R17656C2: got 'X'”
# Warning message:
# “Expecting numeric in B17657 / R17657C2: got 'X'”
# Warning message:
# “Expecting numeric in B17658 / R17658C2: got 'X'”
# Warning message:
# “Expecting numeric in B17659 / R17659C2: got 'X'”
# Warning message:
# “Expecting numeric in B17660 / R17660C2: got 'X'”
# Warning message:
# “Expecting numeric in B17661 / R17661C2: got 'X'”
# Warning message:
# “Expecting numeric in B17662 / R17662C2: got 'X'”
# Warning message:
# “Expecting numeric in B17663 / R17663C2: got 'X'”
# Warning message:
# “Expecting numeric in B17664 / R17664C2: got 'X'”
# Warning message:
# “Expecting numeric in B17665 / R17665C2: got 'X'”
# Warning message:
# “Expecting numeric in B17666 / R17666C2: got 'X'”
# Warning message:
# “Expecting numeric in B17667 / R17667C2: got 'X'”
# Warning message:
# “Expecting numeric in B17668 / R17668C2: got 'X'”
# Warning message:
# “Expecting numeric in B17669 / R17669C2: got 'X'”
# Warning message:
# “Expecting numeric in B17670 / R17670C2: got 'X'”
# Warning message:
# “Expecting numeric in B17671 / R17671C2: got 'X'”
# Warning message:
# “Expecting numeric in B17672 / R17672C2: got 'X'”
# Warning message:
# “Expecting numeric in B17673 / R17673C2: got 'X'”
# Warning message:
# “Expecting numeric in B17674 / R17674C2: got 'X'”
# Warning message:
# “Expecting numeric in B17675 / R17675C2: got 'X'”
# Warning message:
# “Expecting numeric in B17676 / R17676C2: got 'X'”
# Warning message:
# “Expecting numeric in B17677 / R17677C2: got 'X'”
# Warning message:
# “Expecting numeric in B17678 / R17678C2: got 'X'”
# Warning message:
# “Expecting numeric in B17679 / R17679C2: got 'X'”
# Warning message:
# “Expecting numeric in B17680 / R17680C2: got 'X'”
# Warning message:
# “Expecting numeric in B17681 / R17681C2: got 'X'”
# Warning message:
# “Expecting numeric in B17682 / R17682C2: got 'X'”
# Warning message:
# “Expecting numeric in B17683 / R17683C2: got 'X'”
# Warning message:
# “Expecting numeric in B17684 / R17684C2: got 'X'”
# Warning message:
# “Expecting numeric in B17685 / R17685C2: got 'X'”
# Warning message:
# “Expecting numeric in B17686 / R17686C2: got 'X'”
# Warning message:
# “Expecting numeric in B17687 / R17687C2: got 'X'”
# Warning message:
# “Expecting numeric in B17688 / R17688C2: got 'X'”
# Warning message:
# “Expecting numeric in B17689 / R17689C2: got 'X'”
# Warning message:
# “Expecting numeric in B17690 / R17690C2: got 'X'”
# Warning message:
# “Expecting numeric in B17691 / R17691C2: got 'X'”
# Warning message:
# “Expecting numeric in B17692 / R17692C2: got 'X'”
# Warning message:
# “Expecting numeric in B17693 / R17693C2: got 'X'”
# Warning message:
# “Expecting numeric in B17694 / R17694C2: got 'X'”
# Warning message:
# “Expecting numeric in B17695 / R17695C2: got 'X'”
# Warning message:
# “Expecting numeric in B17696 / R17696C2: got 'X'”
# Warning message:
# “Expecting numeric in B17697 / R17697C2: got 'X'”
# Warning message:
# “Expecting numeric in B17698 / R17698C2: got 'X'”
# Warning message:
# “Expecting numeric in B17699 / R17699C2: got 'X'”
# Warning message:
# “Expecting numeric in B17700 / R17700C2: got 'X'”
# Warning message:
# “Expecting numeric in B17701 / R17701C2: got 'X'”
# Warning message:
# “Expecting numeric in B17702 / R17702C2: got 'X'”
# Warning message:
# “Expecting numeric in B17703 / R17703C2: got 'X'”
# Warning message:
# “Expecting numeric in B17704 / R17704C2: got 'X'”
# Warning message:
# “Expecting numeric in B17705 / R17705C2: got 'X'”
# Warning message:
# “Expecting numeric in B17706 / R17706C2: got 'X'”
# Warning message:
# “Expecting numeric in B17707 / R17707C2: got 'X'”
# Warning message:
# “Expecting numeric in B17708 / R17708C2: got 'X'”
# Warning message:
# “Expecting numeric in B17709 / R17709C2: got 'X'”
# Warning message:
# “Expecting numeric in B17710 / R17710C2: got 'X'”
# Warning message:
# “Expecting numeric in B17711 / R17711C2: got 'X'”
# Warning message:
# “Expecting numeric in B17712 / R17712C2: got 'X'”
# Warning message:
# “Expecting numeric in B17713 / R17713C2: got 'X'”
# Warning message:
# “Expecting numeric in B17714 / R17714C2: got 'X'”
# Warning message:
# “Expecting numeric in B17715 / R17715C2: got 'X'”
# Warning message:
# “Expecting numeric in B17716 / R17716C2: got 'X'”
# Warning message:
# “Expecting numeric in B17717 / R17717C2: got 'X'”
# Warning message:
# “Expecting numeric in B17718 / R17718C2: got 'X'”
# Warning message:
# “Expecting numeric in B17719 / R17719C2: got 'X'”
# Warning message:
# “Expecting numeric in B17720 / R17720C2: got 'X'”
# Warning message:
# “Expecting numeric in B17721 / R17721C2: got 'X'”
# Warning message:
# “Expecting numeric in B17722 / R17722C2: got 'X'”
# Warning message:
# “Expecting numeric in B17723 / R17723C2: got 'X'”
# Warning message:
# “Expecting numeric in B17724 / R17724C2: got 'X'”
# Warning message:
# “Expecting numeric in B17725 / R17725C2: got 'X'”
# Warning message:
# “Expecting numeric in B17726 / R17726C2: got 'X'”
# Warning message:
# “Expecting numeric in B17727 / R17727C2: got 'X'”
# Warning message:
# “Expecting numeric in B17728 / R17728C2: got 'X'”
# Warning message:
# “Expecting numeric in B17729 / R17729C2: got 'X'”
# Warning message:
# “Expecting numeric in B17730 / R17730C2: got 'X'”
# Warning message:
# “Expecting numeric in B17731 / R17731C2: got 'X'”
# Warning message:
# “Expecting numeric in B17732 / R17732C2: got 'X'”
# Warning message:
# “Expecting numeric in B17733 / R17733C2: got 'X'”
# Warning message:
# “Expecting numeric in B17734 / R17734C2: got 'X'”
# Warning message:
# “Expecting numeric in B17735 / R17735C2: got 'X'”
# Warning message:
# “Expecting numeric in B17736 / R17736C2: got 'X'”
# Warning message:
# “Expecting numeric in B17737 / R17737C2: got 'X'”
# Warning message:
# “Expecting numeric in B17738 / R17738C2: got 'X'”
# Warning message:
# “Expecting numeric in B17739 / R17739C2: got 'X'”
# Warning message:
# “Expecting numeric in B17740 / R17740C2: got 'X'”
# Warning message:
# “Expecting numeric in B17741 / R17741C2: got 'X'”
# Warning message:
# “Expecting numeric in B17742 / R17742C2: got 'X'”
# Warning message:
# “Expecting numeric in B17743 / R17743C2: got 'X'”
# Warning message:
# “Expecting numeric in B17744 / R17744C2: got 'X'”
# Warning message:
# “Expecting numeric in B17745 / R17745C2: got 'X'”
# Warning message:
# “Expecting numeric in B17746 / R17746C2: got 'X'”
# Warning message:
# “Expecting numeric in B17747 / R17747C2: got 'X'”
# Warning message:
# “Expecting numeric in B17748 / R17748C2: got 'X'”
# Warning message:
# “Expecting numeric in B17749 / R17749C2: got 'X'”
# Warning message:
# “Expecting numeric in B17750 / R17750C2: got 'X'”
# Warning message:
# “Expecting numeric in B17751 / R17751C2: got 'X'”
# Warning message:
# “Expecting numeric in B17752 / R17752C2: got 'X'”
# Warning message:
# “Expecting numeric in B17753 / R17753C2: got 'X'”
# Warning message:
# “Expecting numeric in B17754 / R17754C2: got 'X'”
# Warning message:
# “Expecting numeric in B17755 / R17755C2: got 'X'”
# Warning message:
# “Expecting numeric in B17756 / R17756C2: got 'X'”
# Warning message:
# “Expecting numeric in B17757 / R17757C2: got 'X'”
# Warning message:
# “Expecting numeric in B17758 / R17758C2: got 'X'”
# Warning message:
# “Expecting numeric in B17759 / R17759C2: got 'X'”
# Warning message:
# “Expecting numeric in B17760 / R17760C2: got 'X'”
# Warning message:
# “Expecting numeric in B17761 / R17761C2: got 'X'”
# Warning message:
# “Expecting numeric in B17762 / R17762C2: got 'X'”
# Warning message:
# “Expecting numeric in B17763 / R17763C2: got 'X'”
# Warning message:
# “Expecting numeric in B17764 / R17764C2: got 'X'”
# Warning message:
# “Expecting numeric in B17765 / R17765C2: got 'X'”
# Warning message:
# “Expecting numeric in B17766 / R17766C2: got 'X'”
# Warning message:
# “Expecting numeric in B17767 / R17767C2: got 'X'”
# Warning message:
# “Expecting numeric in B17768 / R17768C2: got 'X'”
# Warning message:
# “Expecting numeric in B17769 / R17769C2: got 'X'”
# Warning message:
# “Expecting numeric in B17770 / R17770C2: got 'X'”
# Warning message:
# “Expecting numeric in B17771 / R17771C2: got 'X'”
# Warning message:
# “Expecting numeric in B17772 / R17772C2: got 'X'”
# Warning message:
# “Expecting numeric in B17773 / R17773C2: got 'X'”
# Warning message:
# “Expecting numeric in B17774 / R17774C2: got 'X'”
# Warning message:
# “Expecting numeric in B17775 / R17775C2: got 'X'”
# Warning message:
# “Expecting numeric in B17776 / R17776C2: got 'X'”
# Warning message:
# “Expecting numeric in B17777 / R17777C2: got 'X'”
# Warning message:
# “Expecting numeric in B17778 / R17778C2: got 'X'”
# Warning message:
# “Expecting numeric in B17779 / R17779C2: got 'X'”
# Warning message:
# “Expecting numeric in B17780 / R17780C2: got 'X'”
# Warning message:
# “Expecting numeric in B17781 / R17781C2: got 'X'”
# Warning message:
# “Expecting numeric in B17782 / R17782C2: got 'X'”
# Warning message:
# “Expecting numeric in B17783 / R17783C2: got 'X'”
# Warning message:
# “Expecting numeric in B17784 / R17784C2: got 'X'”
# Warning message:
# “Expecting numeric in B17785 / R17785C2: got 'X'”
# Warning message:
# “Expecting numeric in B17786 / R17786C2: got 'X'”
# Warning message:
# “Expecting numeric in B17787 / R17787C2: got 'X'”
# Warning message:
# “Expecting numeric in B17788 / R17788C2: got 'X'”
# Warning message:
# “Expecting numeric in B17789 / R17789C2: got 'X'”
# Warning message:
# “Expecting numeric in B17790 / R17790C2: got 'X'”
# Warning message:
# “Expecting numeric in B17791 / R17791C2: got 'X'”
# Warning message:
# “Expecting numeric in B17792 / R17792C2: got 'X'”
# Warning message:
# “Expecting numeric in B17793 / R17793C2: got 'X'”
# Warning message:
# “Expecting numeric in B17794 / R17794C2: got 'X'”
# Warning message:
# “Expecting numeric in B17795 / R17795C2: got 'X'”
# Warning message:
# “Expecting numeric in B17796 / R17796C2: got 'X'”
# Warning message:
# “Expecting numeric in B17797 / R17797C2: got 'X'”
# Warning message:
# “Expecting numeric in B17798 / R17798C2: got 'X'”
# Warning message:
# “Expecting numeric in B17799 / R17799C2: got 'X'”
# Warning message:
# “Expecting numeric in B17800 / R17800C2: got 'X'”
# Warning message:
# “Expecting numeric in B17801 / R17801C2: got 'X'”
# Warning message:
# “Expecting numeric in B17802 / R17802C2: got 'X'”
# Warning message:
# “Expecting numeric in B17803 / R17803C2: got 'X'”
# Warning message:
# “Expecting numeric in B17804 / R17804C2: got 'X'”
# Warning message:
# “Expecting numeric in B17805 / R17805C2: got 'X'”
# Warning message:
# “Expecting numeric in B17806 / R17806C2: got 'X'”
# Warning message:
# “Expecting numeric in B17807 / R17807C2: got 'X'”
# Warning message:
# “Expecting numeric in B17808 / R17808C2: got 'X'”
# Warning message:
# “Expecting numeric in B17809 / R17809C2: got 'X'”
# Warning message:
# “Expecting numeric in B17810 / R17810C2: got 'X'”
# Warning message:
# “Expecting numeric in B17811 / R17811C2: got 'X'”
# Warning message:
# “Expecting numeric in B17812 / R17812C2: got 'X'”
# Warning message:
# “Expecting numeric in B17813 / R17813C2: got 'X'”
# Warning message:
# “Expecting numeric in B17814 / R17814C2: got 'X'”
# Warning message:
# “Expecting numeric in B17815 / R17815C2: got 'X'”
# Warning message:
# “Expecting numeric in B17816 / R17816C2: got 'X'”
# Warning message:
# “Expecting numeric in B17817 / R17817C2: got 'X'”
# Warning message:
# “Expecting numeric in B17818 / R17818C2: got 'X'”
# Warning message:
# “Expecting numeric in B17819 / R17819C2: got 'X'”
# Warning message:
# “Expecting numeric in B17820 / R17820C2: got 'X'”
# Warning message:
# “Expecting numeric in B17821 / R17821C2: got 'X'”
# Warning message:
# “Expecting numeric in B17822 / R17822C2: got 'X'”
# Warning message:
# “Expecting numeric in B17823 / R17823C2: got 'X'”
# Warning message:
# “Expecting numeric in B17824 / R17824C2: got 'X'”
# Warning message:
# “Expecting numeric in B17825 / R17825C2: got 'X'”
# Warning message:
# “Expecting numeric in B17826 / R17826C2: got 'X'”
# Warning message:
# “Expecting numeric in B17827 / R17827C2: got 'X'”
# Warning message:
# “Expecting numeric in B17828 / R17828C2: got 'X'”
# Warning message:
# “Expecting numeric in B17829 / R17829C2: got 'X'”
# Warning message:
# “Expecting numeric in B17830 / R17830C2: got 'X'”
# Warning message:
# “Expecting numeric in B17831 / R17831C2: got 'X'”
# Warning message:
# “Expecting numeric in B17832 / R17832C2: got 'X'”
# Warning message:
# “Expecting numeric in B17833 / R17833C2: got 'X'”
# Warning message:
# “Expecting numeric in B17834 / R17834C2: got 'X'”
# Warning message:
# “Expecting numeric in B17835 / R17835C2: got 'X'”
# Warning message:
# “Expecting numeric in B17836 / R17836C2: got 'X'”
# Warning message:
# “Expecting numeric in B17837 / R17837C2: got 'X'”
# Warning message:
# “Expecting numeric in B17838 / R17838C2: got 'X'”
# Warning message:
# “Expecting numeric in B17839 / R17839C2: got 'X'”
# Warning message:
# “Expecting numeric in B17840 / R17840C2: got 'X'”
# Warning message:
# “Expecting numeric in B17841 / R17841C2: got 'X'”
# Warning message:
# “Expecting numeric in B17842 / R17842C2: got 'X'”
# Warning message:
# “Expecting numeric in B17843 / R17843C2: got 'X'”
# Warning message:
# “Expecting numeric in B17844 / R17844C2: got 'X'”
# Warning message:
# “Expecting numeric in B17845 / R17845C2: got 'X'”
# Warning message:
# “Expecting numeric in B17846 / R17846C2: got 'X'”
# Warning message:
# “Expecting numeric in B17847 / R17847C2: got 'X'”
# Warning message:
# “Expecting numeric in B17848 / R17848C2: got 'X'”
# Warning message:
# “Expecting numeric in B17849 / R17849C2: got 'X'”
# Warning message:
# “Expecting numeric in B17850 / R17850C2: got 'X'”
# Warning message:
# “Expecting numeric in B17851 / R17851C2: got 'X'”
# Warning message:
# “Expecting numeric in B17852 / R17852C2: got 'X'”
# Warning message:
# “Expecting numeric in B17853 / R17853C2: got 'X'”
# Warning message:
# “Expecting numeric in B17854 / R17854C2: got 'X'”
# Warning message:
# “Expecting numeric in B17855 / R17855C2: got 'X'”
# Warning message:
# “Expecting numeric in B17856 / R17856C2: got 'X'”
# Warning message:
# “Expecting numeric in B17857 / R17857C2: got 'X'”
# Warning message:
# “Expecting numeric in B17858 / R17858C2: got 'X'”
# Warning message:
# “Expecting numeric in B17859 / R17859C2: got 'X'”
# Warning message:
# “Expecting numeric in B17860 / R17860C2: got 'X'”
# Warning message:
# “Expecting numeric in B17861 / R17861C2: got 'X'”
# Warning message:
# “Expecting numeric in B17862 / R17862C2: got 'X'”
# Warning message:
# “Expecting numeric in B17863 / R17863C2: got 'X'”
# Warning message:
# “Expecting numeric in B17864 / R17864C2: got 'X'”
# Warning message:
# “Expecting numeric in B17865 / R17865C2: got 'X'”
# Warning message:
# “Expecting numeric in B17866 / R17866C2: got 'X'”
# Warning message:
# “Expecting numeric in B17867 / R17867C2: got 'X'”
# Warning message:
# “Expecting numeric in B17868 / R17868C2: got 'X'”
# Warning message:
# “Expecting numeric in B17869 / R17869C2: got 'X'”
# Warning message:
# “Expecting numeric in B17870 / R17870C2: got 'X'”
# Warning message:
# “Expecting numeric in B17871 / R17871C2: got 'X'”
# Warning message:
# “Expecting numeric in B17872 / R17872C2: got 'X'”
# Warning message:
# “Expecting numeric in B17873 / R17873C2: got 'X'”
# Warning message:
# “Expecting numeric in B17874 / R17874C2: got 'X'”
# Warning message:
# “Expecting numeric in B17875 / R17875C2: got 'X'”
# Warning message:
# “Expecting numeric in B17876 / R17876C2: got 'X'”
# Warning message:
# “Expecting numeric in B17877 / R17877C2: got 'X'”
# Warning message:
# “Expecting numeric in B17878 / R17878C2: got 'X'”
# Warning message:
# “Expecting numeric in B17879 / R17879C2: got 'X'”
# Warning message:
# “Expecting numeric in B17880 / R17880C2: got 'X'”
# Warning message:
# “Expecting numeric in B17881 / R17881C2: got 'X'”
# Warning message:
# “Expecting numeric in B17882 / R17882C2: got 'X'”
# Warning message:
# “Expecting numeric in B17883 / R17883C2: got 'X'”
# Warning message:
# “Expecting numeric in B17884 / R17884C2: got 'X'”
# Warning message:
# “Expecting numeric in B17885 / R17885C2: got 'X'”
# Warning message:
# “Expecting numeric in B17886 / R17886C2: got 'X'”
# Warning message:
# “Expecting numeric in B17887 / R17887C2: got 'X'”
# Warning message:
# “Expecting numeric in B17888 / R17888C2: got 'X'”
# Warning message:
# “Expecting numeric in B17889 / R17889C2: got 'X'”
# Warning message:
# “Expecting numeric in B17890 / R17890C2: got 'X'”
# Warning message:
# “Expecting numeric in B17891 / R17891C2: got 'X'”
# Warning message:
# “Expecting numeric in B17892 / R17892C2: got 'X'”
# Warning message:
# “Expecting numeric in B17893 / R17893C2: got 'X'”
# Warning message:
# “Expecting numeric in B17894 / R17894C2: got 'X'”
# Warning message:
# “Expecting numeric in B17895 / R17895C2: got 'X'”
# Warning message:
# “Expecting numeric in B17896 / R17896C2: got 'X'”
# Warning message:
# “Expecting numeric in B17897 / R17897C2: got 'X'”
# Warning message:
# “Expecting numeric in B17898 / R17898C2: got 'X'”
# Warning message:
# “Expecting numeric in B17899 / R17899C2: got 'X'”
# Warning message:
# “Expecting numeric in B17900 / R17900C2: got 'X'”
# Warning message:
# “Expecting numeric in B17901 / R17901C2: got 'X'”
# Warning message:
# “Expecting numeric in B17902 / R17902C2: got 'X'”
# Warning message:
# “Expecting numeric in B17903 / R17903C2: got 'X'”
# Warning message:
# “Expecting numeric in B17904 / R17904C2: got 'X'”
# Warning message:
# “Expecting numeric in B17905 / R17905C2: got 'X'”
# Warning message:
# “Expecting numeric in B17906 / R17906C2: got 'X'”
# Warning message:
# “Expecting numeric in B17907 / R17907C2: got 'X'”
# Warning message:
# “Expecting numeric in B17908 / R17908C2: got 'X'”
# Warning message:
# “Expecting numeric in B17909 / R17909C2: got 'X'”
# Warning message:
# “Expecting numeric in B17910 / R17910C2: got 'X'”
# Warning message:
# “Expecting numeric in B17911 / R17911C2: got 'X'”
# Warning message:
# “Expecting numeric in B17912 / R17912C2: got 'X'”
# Warning message:
# “Expecting numeric in B17913 / R17913C2: got 'X'”
# Warning message:
# “Expecting numeric in B17914 / R17914C2: got 'X'”
# Warning message:
# “Expecting numeric in B17915 / R17915C2: got 'X'”
# Warning message:
# “Expecting numeric in B17916 / R17916C2: got 'X'”
# Warning message:
# “Expecting numeric in B17917 / R17917C2: got 'X'”
# Warning message:
# “Expecting numeric in B17918 / R17918C2: got 'X'”
# Warning message:
# “Expecting numeric in B17919 / R17919C2: got 'X'”
# Warning message:
# “Expecting numeric in B17920 / R17920C2: got 'X'”
# Warning message:
# “Expecting numeric in B17921 / R17921C2: got 'X'”
# Warning message:
# “Expecting numeric in B17922 / R17922C2: got 'X'”
# Warning message:
# “Expecting numeric in B17923 / R17923C2: got 'X'”
# Warning message:
# “Expecting numeric in B17924 / R17924C2: got 'X'”
# Warning message:
# “Expecting numeric in B17925 / R17925C2: got 'X'”
# Warning message:
# “Expecting numeric in B17926 / R17926C2: got 'X'”
# Warning message:
# “Expecting numeric in B17927 / R17927C2: got 'X'”
# Warning message:
# “Expecting numeric in B17928 / R17928C2: got 'X'”
# Warning message:
# “Expecting numeric in B17929 / R17929C2: got 'X'”
# Warning message:
# “Expecting numeric in B17930 / R17930C2: got 'X'”
# Warning message:
# “Expecting numeric in B17931 / R17931C2: got 'X'”
# Warning message:
# “Expecting numeric in B17932 / R17932C2: got 'X'”
# Warning message:
# “Expecting numeric in B17933 / R17933C2: got 'X'”
# Warning message:
# “Expecting numeric in B17934 / R17934C2: got 'X'”
# Warning message:
# “Expecting numeric in B17935 / R17935C2: got 'X'”
# Warning message:
# “Expecting numeric in B17936 / R17936C2: got 'X'”
# Warning message:
# “Expecting numeric in B17937 / R17937C2: got 'X'”
# Warning message:
# “Expecting numeric in B17938 / R17938C2: got 'X'”
# Warning message:
# “Expecting numeric in B17939 / R17939C2: got 'X'”
# Warning message:
# “Expecting numeric in B17940 / R17940C2: got 'X'”
# Warning message:
# “Expecting numeric in B17941 / R17941C2: got 'X'”
# Warning message:
# “Expecting numeric in B17942 / R17942C2: got 'X'”
# Warning message:
# “Expecting numeric in B17943 / R17943C2: got 'X'”
# Warning message:
# “Expecting numeric in B17944 / R17944C2: got 'X'”
# Warning message:
# “Expecting numeric in B17945 / R17945C2: got 'X'”
# Warning message:
# “Expecting numeric in B17946 / R17946C2: got 'X'”
# Warning message:
# “Expecting numeric in B17947 / R17947C2: got 'X'”
# Warning message:
# “Expecting numeric in B17948 / R17948C2: got 'X'”
# Warning message:
# “Expecting numeric in B17949 / R17949C2: got 'X'”
# Warning message:
# “Expecting numeric in B17950 / R17950C2: got 'X'”
# Warning message:
# “Expecting numeric in B17951 / R17951C2: got 'X'”
# Warning message:
# “Expecting numeric in B17952 / R17952C2: got 'X'”
# Warning message:
# “Expecting numeric in B17953 / R17953C2: got 'X'”
# Warning message:
# “Expecting numeric in B17954 / R17954C2: got 'X'”
# Warning message:
# “Expecting numeric in B17955 / R17955C2: got 'X'”
# Warning message:
# “Expecting numeric in B17956 / R17956C2: got 'X'”
# Warning message:
# “Expecting numeric in B17957 / R17957C2: got 'X'”
# Warning message:
# “Expecting numeric in B17958 / R17958C2: got 'X'”
# Warning message:
# “Expecting numeric in B17959 / R17959C2: got 'X'”
# Warning message:
# “Expecting numeric in B17960 / R17960C2: got 'X'”
# Warning message:
# “Expecting numeric in B17961 / R17961C2: got 'X'”
# Warning message:
# “Expecting numeric in B17962 / R17962C2: got 'X'”
# Warning message:
# “Expecting numeric in B17963 / R17963C2: got 'X'”
# Warning message:
# “Expecting numeric in B17964 / R17964C2: got 'X'”
# Warning message:
# “Expecting numeric in B17965 / R17965C2: got 'X'”
# Warning message:
# “Expecting numeric in B17966 / R17966C2: got 'X'”
# Warning message:
# “Expecting numeric in B17967 / R17967C2: got 'X'”
# Warning message:
# “Expecting numeric in B17968 / R17968C2: got 'X'”
# Warning message:
# “Expecting numeric in B17969 / R17969C2: got 'X'”
# Warning message:
# “Expecting numeric in B17970 / R17970C2: got 'X'”
# Warning message:
# “Expecting numeric in B17971 / R17971C2: got 'X'”

# %%
head(dat,2)
# Out:
#   EnsemblID       Chromosome Start  Stop   Strand Band   Gene   TF/Cofactor
# 1 ENSG00000186092 1           65419  71585 1      p36.33 OR4F5  0
# 2 ENSG00000187634 1          923928 944581 1      p36.33 SAMD11 0
#   Oncogene TumorSuppressorGene CancerCensusGene
# 1 0        0                   0
# 2 0        0                   0

# %%
TFs = dat$Gene[ dat[,"TF/Cofactor"]==1]
oncogene = dat$Gene[ dat$Oncogene==1]
tumorsuppr = dat$Gene[ dat$TumorSuppressorGene==1]
cancerCensus = dat$Gene[ dat$CancerCensusGene==1]

# %%
# pathway definitions
pwCategories = readRDS(file = "pathway-categories.rds")
genesPerPathway = unlist(unname(pwCategories),recursive = F)

# %%
signalingGenes = unique(sort(unname(unlist(pwCategories$signalingPWs))))
immuneGenes = unique(sort(unname(unlist(pwCategories$immunePWs))))
metabolicGenes = unique(sort(unname(unlist(pwCategories$metabolicPWs))))
geneList = list("immuneGenes"=immuneGenes, "metabolicGenes"=metabolicGenes, 
                "signalingGenes"=signalingGenes, "cancerCensus"=cancerCensus,
                "oncogene"=oncogene,"tumorsuppr"=tumorsuppr,"TFs"= TFs)

# %%
cancerGenes = sort(unique(c(cancerCensus, tumorsuppr, oncogene)))
metabRestGenes = setdiff(metabolicGenes,cancerGenes)
signalRestGenes = setdiff(signalingGenes, cancerGenes)
TFrestGenes = setdiff(TFs, cancerGenes)

# %%
getGeneCateg = function(genes) {
    categs = rep("gene",length(genes))
    wh = which(genes %in% cancerGenes); categs[wh] = "cancer"
    wh = which(genes %in% metabRestGenes); categs[wh] = "metabolism"
    wh = which(genes %in% signalRestGenes); categs[wh] = "signaling"
    wh = which(genes %in% TFrestGenes); categs[wh] = "TF"
    categs
}

# %%
categColors = c("TF" = "#4444FF","metabolism"="orange",
            "cancer"="red","signaling"="green","gene"="grey")
geneColors = c("up"="red","down"="#008800","target"="#6666FF", "mixed"="#884400")

# %%
samplePairGroupNiceNames = c("SG1"="higher","SG3" = "slightly lower", "SG2"="lower")

# %% [markdown]
# ### impact log-rations of all altered genes on all genes, for each metastases pair:

# %%
tmp = readRDS(file="metPairs-impactRatios-onAllTargetGenes.rds")
logMedianImpRatios = tmp$logMedianImpRatios
logMedianImpRatios[[1]][1:3,1:4]
# Out:
#        NOC2L    KLHL17     HES4       ISG15
# AIM2   1.374143 -0.7504903  1.9597567 -0.1946618
# CDCA7  1.023686  2.3013262  2.3037679  1.2259988
# ELOVL6 1.684978  1.1693858 -0.6388257  2.0923128

# %%
samplePairPerSubgroup[["SG1"]]
# Out:
# [1] "P04_BSki_1" "P08_BSof_2" "P16_BLun"   "P42_BLym_1"

# %%
perGroupMeanLogImp

# %%
# individual and mean group log impact ratios of the top genes:
perGroupLogImpMat = NULL
for( sg in names(samplePairPerSubgroup)) {
    logImpMat = NULL
    for(sp in samplePairPerSubgroup[[sg]]) {
        logImpMat = rbind(logImpMat, colMeans(logMedianImpRatios[[sp]], na.rm = T))
    }
    #  remove genes which have any NA entry:
    wh = which(apply(logImpMat,2,function(c) all(!is.na(c)) ))
    logImpMat = logImpMat[,wh]
    perGroupLogImpMat[ length(perGroupLogImpMat)+1] = list(logImpMat)
}
names(perGroupLogImpMat) = names(samplePairPerSubgroup)

# %%
perGroupLogImpMat[[1]][1:3,1:4]
# Out:
#      NOC2L       KLHL17       HES4       ISG15
# [1,]  0.26236469  0.519595131  0.3757407 0.2964649
# [2,] -0.04970504 -0.268292358 -0.0149790 0.3010572
# [3,]  0.19782059 -0.008449568 -1.1914267 0.3986933

# %%
perGroupMeanLogImp = NULL
for (sg in names(samplePairPerSubgroup)) {
    # for each sample pair, mean impact from DEGs on each target:
    samplePairGroupMeanLogImp = sapply(samplePairPerSubgroup[[sg]],
                           function(sp) colMeans(logMedianImpRatios[[sp]],na.rm = T))
    # only genes present in all sample pairs:
    wh = which(apply(samplePairGroupMeanLogImp,1,function(r) length(which(is.na(r))))==0)
    samplePairGroupMeanLogImp = samplePairGroupMeanLogImp[wh,]
    # now mean over all sample pairs for each target gene:
    meanGroupMeanLogImp = apply(samplePairGroupMeanLogImp,1,mean,na.omit=T)
    perGroupMeanLogImp[length(perGroupMeanLogImp)+1] = list(meanGroupMeanLogImp)
}
names(perGroupMeanLogImp) = names(samplePairPerSubgroup)

# %% [markdown]
# ### source gene - target gene interactions

# %%
topInteractions = NULL
for(sampleName in names(regGenesPerPat)) {
    logRatioLong = melt(logMedianImpRatios[[sampleName]], 
                        varnames = c("source","target"), value.name = "log_impact_ratio")
    logRatioLong$source = as.character(logRatioLong$source)
    logRatioLong$target = as.character(logRatioLong$target)
    # remove NaN, NA values:
    wh = which(is.nan(logRatioLong$log_impact_ratio) | is.na(logRatioLong$log_impact_ratio))
    if(length(wh)>0) {
        logRatioLong = logRatioLong[-wh,]
    }
    topUp = logRatioLong[ order(logRatioLong$log_impact_ratio, decreasing = T),]
    topUp = topUp[ which(topUp$log_impact_ratio>0),]
    topDwn = logRatioLong[ order(logRatioLong$log_impact_ratio, decreasing = T),]
    topDwn = topDwn[ which(topDwn$log_impact_ratio<0),]
    topInteractions = 
        rbind(topInteractions,
              data.frame(sample_pair = sampleName, rbind(topUp,topDwn)))
}

# %%
head(topInteractions)
# Out:
#        sample_pair source  target   log_impact_ratio
# 40381  P03_BLun    RAB37   ARNTL2   12.39169
# 80768  P03_BLun    SDK2    IGFBP4   11.02077
# 85576  P03_BLun    RAB37   RNF157   10.95368
# 179630 P03_BLun    GIMAP1  KIAA1161 10.73148
# 107456 P03_BLun    GIMAP1  SLC1A4   10.69105
# 153331 P03_BLun    CBFA2T3 GM2A     10.49999

# %%
topInteractCoord = cbind(sample_pair = topInteractions$sample_pair,
     source = topInteractions$source, geneAnnot[ topInteractions$source,c("chr","pos")],
      target = topInteractions$target, geneAnnot[ topInteractions$target,c("chr","pos")],
      log_impact_ratio = topInteractions$log_impact_ratio)
colnames(topInteractCoord) = c("sample_pair","source_gene","source_chr","source_pos",
                               "target_gene","target_chr","target_pos","log_impact_ratio")
topInteractCoord$direction = ifelse(topInteractCoord$log_impact_ratio>0,1,2)

# %%
head(topInteractCoord)
# Out:
#          sample_pair source_gene source_chr source_pos target_gene target_chr
# RAB37    P03_BLun    RAB37       chr17       72705096  ARNTL2      chr12
# SDK2     P03_BLun    SDK2        chr17       71485376  IGFBP4      chr17
# RAB37.1  P03_BLun    RAB37       chr17       72705096  RNF157      chr17
# GIMAP1   P03_BLun    GIMAP1      chr7       150417508  KIAA1161    chr9
# GIMAP1.1 P03_BLun    GIMAP1      chr7       150417508  SLC1A4      chr2
# CBFA2T3  P03_BLun    CBFA2T3     chr16       88992439  GM2A        chr5
#          target_pos log_impact_ratio direction
# RAB37     27531014  12.39169         1
# SDK2      38606842  11.02077         1
# RAB37.1   74187494  10.95368         1
# GIMAP1    34371760  10.73148         1
# GIMAP1.1  65233305  10.69105         1
# CBFA2T3  150620856  10.49999         1

# %% [markdown]
# ### top/bottom genes based on mean logImpRatio wo/ inconsistent genes

# %%
topConsistent = NULL
for(gr in names(samplePairPerSubgroup)) {
    m = perGroupLogImpMat[[gr]] # log impact ratios of this group
    m = m[, which(apply(m,2,function(c) all(c>0))) ]# only cols with positive log imp
    if(ncol(m)<1) { next } # n.b. lower and slightly lower have no results
    meanLogImp = apply(m,2,mean)
    m = meanLogImp[ order(meanLogImp,decreasing = T)][1:10]
    m = m[which(m>0)]
    cat(gr,"  ", length(m),"  genes\n")
    if(length(m)==0){next}
    tmp = data.frame(group = gr, gene = names(m), 
                     mean_impact = unname(m), stringsAsFactors = F)
    topConsistent = rbind(topConsistent,tmp)
}
topConsistent = topConsistent[order(topConsistent$group,topConsistent$mean_impact, decreasing = T),]
topConsistent
# no genes for lower and slightly lower group
# Out:
# SG1    10   genes
# SG3    4   genes
# SG2    3   genes
#    group gene     mean_impact
# 11 SG3   LIPT1    0.7061245
# 12 SG3   LY75     0.2627015
# 13 SG3   CAPZA2   0.1921801
# 14 SG3   ZNF518B  0.1772573
# 15 SG2   SUSD1    0.6184448
# 16 SG2   EFCAB4B  0.6124077
# 17 SG2   CELSR3   0.1527284
# 1  SG1   RNH1     2.4906067
# 2  SG1   ZNF225   1.9900779
# 3  SG1   PIAS2    1.6434082
# 4  SG1   OCIAD2   1.2961249
# 5  SG1   RB1      1.1154138
# 6  SG1   SORBS3   1.0716262
# 7  SG1   ARHGEF17 1.0453949
# 8  SG1   SMAD3    1.0159536
# 9  SG1   CEACAM1  0.9963748
# 10 SG1   TRIM47   0.9935000

# %%
bottomConsistent = NULL
for(gr in names(samplePairPerSubgroup)) {
    m = perGroupLogImpMat[[gr]] # log impact ratios of this group
    m = m[, which(apply(m,2,function(c) all(c<0))) ] # only cols with negative log imp
    if(ncol(m)<1) { next } # 
    meanLogImp = apply(m,2,mean)
    m = meanLogImp[ order(meanLogImp,decreasing = F)][1:10]
    m = m[which(m<0)]
    cat(gr,"  ", length(m),"  genes\n")
    if(length(m)==0){next}
    tmp = data.frame(group = gr, gene = names(m), 
                     mean_impact = unname(m), stringsAsFactors = F)
    bottomConsistent = rbind(bottomConsistent,tmp)
}
bottomConsistent = bottomConsistent[order(bottomConsistent$group,bottomConsistent$mean_impact),]
bottomConsistent
#
# Out:
# SG1    10   genes
# SG3    10   genes
# SG2    10   genes
#    group gene    mean_impact
# 1  SG1   NCOA7   -1.2836680
# 2  SG1   GLUL    -0.8498034
# 3  SG1   HCST    -0.8086812
# 4  SG1   FBP1    -0.8002054
# 5  SG1   GADD45G -0.7146114
# 6  SG1   CBFA2T3 -0.6712198
# 7  SG1   NLRP1   -0.5785882
# 8  SG1   RIMS3   -0.5743246
# 9  SG1   CNDP2   -0.5123547
# 10 SG1   PPIA    -0.4795329
# 21 SG2   FERMT3  -3.8140590
# 22 SG2   PLB1    -3.0083300
# 23 SG2   SAMD13  -2.8005833
# 24 SG2   LCP2    -2.7077058
# 25 SG2   TC2N    -2.6994256
# 26 SG2   ENPP2   -2.4844756
# 27 SG2   SKAP1   -2.3857899
# 28 SG2   EIF4E3  -2.3153823
# 29 SG2   PES1    -2.2662598
# 30 SG2   BZRAP1  -2.2455731
# 11 SG3   APBA2   -1.4234021
# 12 SG3   EIF4E3  -1.2137110
# 13 SG3   TNK1    -1.1737268
# 14 SG3   MED21   -1.0274028
# 15 SG3   ENOX2   -1.0051594
# 16 SG3   N6AMT2  -0.9786126
# 17 SG3   GGCT    -0.9699241
# 18 SG3   CDK8    -0.9621974
# 19 SG3   KCTD1   -0.9446396
# 20 SG3   RASSF2  -0.9373643

# %% [markdown]
# # circos plots

# %% [markdown]
# for each cluster group:
# - top and bottom 10 target genes with highest/lowest mean log impact
# - for them the top 100 abs(log_impact_ratios) from all possible target genes
# - label for each DEG how many sample pairs they appear in

# %% [markdown]
# ## circos + gene lists from consistenly ranked target genes
# rank genes by mean log impact ratio within a groups sample pairs, removing genes that are inconsistent (not all negative/positive ratio)

# %%
plotGroupCircosConsistent = function(groupName = "higher") {
    
    # top and bottom 10 target genes with highest/lowest mean log impact in that group:
    topGenes = topConsistent$gene[ topConsistent$group == groupName]
    bottomGenes = bottomConsistent$gene[ bottomConsistent$group == groupName]
    length(topGenes)
    length(bottomGenes)
    
    # all interactions in that group to top and bottom target genes:
    # n.b. topInteractCoord contains all interactions for all sample pairs, sorted by log impact ratio
    groupInteractions = topInteractCoord[ topInteractCoord$sample_pair %in% samplePairPerSubgroup[[groupName]],]
    # reduce to top and bottom target genes:
    groupInteractions = groupInteractions[ groupInteractions$target_gene %in% c(topGenes, bottomGenes), ]
    head(groupInteractions)
    
    # for each source gene, add num of sample pairs in which it is DEG:
    altGenesSub = altGenes[ altGenes$samplePair %in% samplePairPerSubgroup[[groupName]] ,]
    tmp = sort(table(altGenesSub$gene), decreasing = T)
    frqPerGene = as.numeric(tmp); names(frqPerGene) = names(tmp)
    groupInteractions$frqDEG = frqPerGene[groupInteractions$source_gene]
    
    # mean log imp ratio between all source and target genes in this group:
    meanGroupInteractions = aggregate(groupInteractions$log_impact_ratio, 
                                      by = list(source_gene = groupInteractions$source_gene, 
                                                target_gene=groupInteractions$target_gene), FUN = mean)
    colnames(meanGroupInteractions)[3]="mean_log_impact_ratio"
    meanGroupInteractions$frqDEG = frqPerGene[meanGroupInteractions$source_gene]
    meanGroupInteractions = cbind(meanGroupInteractions,geneAnnot[ meanGroupInteractions$source_gene,c("chr","pos")])
    colnames(meanGroupInteractions)[c(5,6)]=c("source_chr","source_pos")
    meanGroupInteractions = cbind(meanGroupInteractions,geneAnnot[ meanGroupInteractions$target_gene,c("chr","pos")])
    colnames(meanGroupInteractions)[c(7,8)]=c("target_chr","target_pos")
    
    # sort by frqDEG (numer of sample pairs in which it is DEG) and abs(mean_log_impact_ratio):
    meanGroupInteractions = meanGroupInteractions[ order(-meanGroupInteractions$frqDEG, -abs(meanGroupInteractions$mean_log_impact_ratio)),]
    meanGroupInteractions$direction = ifelse(meanGroupInteractions$mean_log_impact_ratio>0,1,2)
    # remove chrY interactions:
    wh = which(meanGroupInteractions$source_chr=="chrY" | meanGroupInteractions$target_chr=="chrY")
    if(length(wh)>0) {
        meanGroupInteractions = meanGroupInteractions[-wh,]
    }
    # take the abs top 100 interactions:
    topMeanGroupInteractions = head(meanGroupInteractions,100)
    
    altGenesSub = altGenes[ altGenes$samplePair %in% samplePairPerSubgroup[[groupName]] & altGenes$gene %in% topMeanGroupInteractions$source_gene,]
    altGenesSub
    # aggregate expr. direction of group's altGenes:
    #     direction: 1 higher, 2 lower, 1,2  = mixed between sample pairs
    altGenesSubAggr = aggregate(altGenesSub$direction, by = list(gene = altGenesSub$gene), 
        FUN = function(x) paste0(sort(unique(x)),collapse=","))
    altGenesSubAggr = cbind(altGenesSubAggr, geneAnnot[ altGenesSubAggr$gene,c("chr","pos")], y=1)
    colnames(altGenesSubAggr)[2] = "direction"
                            
    # combine source and target genes for plotting:
    targetGannot = geneAnnot[geneAnnot$gene %in% topMeanGroupInteractions$target_gene,]
    targetSourceGene = rbind(altGenesSubAggr[,c("chr","pos","gene","direction")],
                            cbind(targetGannot[,c("chr","pos","gene")], direction="0"))
    targetSourceGene$direction = ifelse(targetSourceGene$direction=="0","target",
                                        ifelse(targetSourceGene$direction==1,"up",
                                               ifelse(targetSourceGene$direction==2,"down","mixed")))
    targetSourceGene$categ = "gene"; targetSourceGene$categ = getGeneCateg(genes = targetSourceGene$gene)

    # for source genes, add in how many SPs it is a DEG
    targetSourceGene$frqDEG[targetSourceGene$direction != "target"] = 
        sapply(targetSourceGene$gene[ targetSourceGene$direction!="target"], 
            function(gene) unique(meanGroupInteractions$frqDEG[ meanGroupInteractions$source_gene == gene]))
    targetSourceGene$geneLabel = targetSourceGene$gene
    wh = which(!is.na(targetSourceGene$frqDEG))
    targetSourceGene$geneLabel[wh] = paste0(targetSourceGene$geneLabel[wh]," (",targetSourceGene$frqDEG[wh],")")

    # n.b., no sense to add in how many sample pairs the target gene is target gene
    #  because its always in almost all sample pairs, but not necessarily from the top source genes
               
    # save log impact for later:
    logImp = round(perGroupMeanLogImp[[groupName]][ targetSourceGene$gene[ targetSourceGene$direction=="target"] ],3)
    targetSourceGene$meanLogImpact = logImp[ targetSourceGene$gene ]
    
    # plot:
    circos.par(points.overflow.warning = FALSE)
    circos.par("track.height" = 0.05)
    # initialize with max extension for each chromosome (0..chr size):
    circos.initializeWithIdeogram(species = "hg19", chromosome.index = chrSizes$chr, plotType="")

                            
    # labels and ticks for target and source genes:
    circos.labels(sectors = targetSourceGene$chr, x = targetSourceGene$pos, labels = targetSourceGene$geneLabel, 
                                  side = "outside", connection_height=mm_h(5), cex=0.7, 
                          line_col=alpha(geneColors[targetSourceGene$direction],0.3),
                         col=geneColors[targetSourceGene$direction])

    circos.track(chrSizes$chr, ylim = c(0,1),
        panel.fun = function(x, y) {
            circos.text(CELL_META$xcenter, CELL_META$cell.ylim[2] + mm_y(3), gsub("chr","",CELL_META$sector.index), cex=0.9)
            circos.axis(labels=F, major.tick=F)
    })
                            
    circos.par(track.margin=c(0,0)) 

    # add colored dot for target source & genes in catagory
    circos.trackPoints(sectors = targetSourceGene$chr, x = targetSourceGene$pos, y = rep(.5,nrow(targetSourceGene)), 
                       col = categColors[targetSourceGene$categ], pch = 16, cex = 0.5)

    # links between source and target genes:
    for(i in 1:nrow(topMeanGroupInteractions)) {
        l = topMeanGroupInteractions[i,]
        circos.link(l$source_chr, l$source_pos, l$target_chr, l$target_pos, h = 0.7, directional = 1, 
            col = c(alpha("darkorange",0.5),alpha("cornflowerblue",0.5))[l$direction],
            #col = c(rgb(1,0.7,0.5,0.5),rgb(0.76,0.86,1,0.5))[l$direction],# lighter colors
            arr.length=0.15)  
    }
    title(main = samplePairGroupNiceNames[groupName], cex.main=0.9)
                                                                             
    # return target genes of the group for literature research
    list(targetGenes = targetSourceGene[ targetSourceGene$direction=="target",],
         sourceGenes = targetSourceGene[ targetSourceGene$direction!="target",])
}

# %%
l = plotGroupCircosConsistent(groupName = "SG1")
targetGenesHigher = l$targetGenes
sourceGenesHigher = l$sourceGenes
# Out:
# Plot with title “higher”

# %%
l = plotGroupCircosConsistent(groupName = "SG3")
targetGenesSlightlyLower = l$targetGenes
sourceGenesSlightlyLower = l$sourceGenes
# Out:
# Plot with title “slightly lower”

# %%
l = plotGroupCircosConsistent(groupName = "SG2")
targetGenesLower = l$targetGenes
sourceGenesLower = l$sourceGenes
# Out:
# Plot with title “lower”

# %%
png(filename = paste0(outDirectory,"Figure-5-circos-topImpactedGenes.png"),
    width = 4000,height = 4000, pointsize = 15, res=400)
par(mfrow = c(2,2))
plotGroupCircosConsistent(groupName = "SG1")
plotGroupCircosConsistent(groupName = "SG3")
plotGroupCircosConsistent(groupName = "SG2")
dev.off()
# Out:
# $targetGenes
#            chr       pos     gene direction      categ frqDEG geneLabel
# RIMS3     chr1  41108840    RIMS3    target       gene     NA     RIMS3
# GLUL      chr1 182356090     GLUL    target metabolism     NA      GLUL
# OCIAD2    chr4  48897995   OCIAD2    target       gene     NA    OCIAD2
# NCOA7     chr6 126177286    NCOA7    target         TF     NA     NCOA7
# PPIA      chr7  44850221     PPIA    target       gene     NA      PPIA
# SORBS3    chr8  22417900   SORBS3    target       gene     NA    SORBS3
# GADD45G   chr9  92220699  GADD45G    target       gene     NA   GADD45G
# FBP1      chr9  97383973     FBP1    target metabolism     NA      FBP1
# RNH1     chr11    500906     RNH1    target       gene     NA      RNH1
# ARHGEF17 chr11  73049735 ARHGEF17    target       gene     NA  ARHGEF17
# RB1      chr13  48967004      RB1    target     cancer     NA       RB1
# SMAD3    chr15  67421817    SMAD3    target     cancer     NA     SMAD3
# CBFA2T3  chr16  88992439  CBFA2T3    target     cancer     NA   CBFA2T3
# NLRP11   chr17   5462746    NLRP1    target       gene     NA     NLRP1
# TRIM47   chr17  73872449   TRIM47    target         TF     NA    TRIM47
# PIAS2    chr18  44444238    PIAS2    target         TF     NA     PIAS2
# CNDP2    chr18  72175708    CNDP2    target metabolism     NA     CNDP2
# HCST     chr19  36394330     HCST    target       gene     NA      HCST
# CEACAM11 chr19  43038421  CEACAM1    target       gene     NA   CEACAM1
# ZNF225   chr19  44626680   ZNF225    target       gene     NA    ZNF225
#          meanLogImpact
# RIMS3           -0.574
# GLUL            -0.850
# OCIAD2           1.296
# NCOA7           -1.284
# PPIA            -0.480
# SORBS3           1.072
# GADD45G         -0.715
# FBP1            -0.800
# RNH1             2.491
# ARHGEF17         1.045
# RB1              1.115
# SMAD3            1.016
# CBFA2T3         -0.671
# NLRP11          -0.579
# TRIM47           0.994
# PIAS2            1.643
# CNDP2           -0.512
# HCST            -0.809
# CEACAM11         0.996
# ZNF225           1.990
#
# $sourceGenes
#             chr       pos      gene direction     categ frqDEG     geneLabel
# CAPG       chr2  85633713      CAPG        up      gene      2      CAPG (2)
# CCDC163P   chr1  45962644  CCDC163P     mixed      gene      2  CCDC163P (2)
# CEACAM1   chr19  43038421   CEACAM1     mixed      gene      2   CEACAM1 (2)
# CPM       chr12  69300664       CPM        up      gene      2       CPM (2)
# DPP4       chr2 162889902      DPP4     mixed      gene      2      DPP4 (2)
# ENPP2      chr8 120627510     ENPP2     mixed      gene      2     ENPP2 (2)
# ESPN       chr1   6503139      ESPN        up      gene      2      ESPN (2)
# FERMT3    chr11  63982752    FERMT3        up        TF      2    FERMT3 (2)
# GCH1      chr14  55339148      GCH1     mixed      gene      2      GCH1 (2)
# IL12RB2    chr1  67817815   IL12RB2     mixed signaling      2   IL12RB2 (2)
# KCNMB4    chr12  70794064    KCNMB4        up      gene      2    KCNMB4 (2)
# KIAA1377  chr11 101828768  KIAA1377     mixed      gene      2  KIAA1377 (2)
# KLHL6      chr3 183239398     KLHL6        up      gene      2     KLHL6 (2)
# MFSD2A     chr1  40428220    MFSD2A        up      gene      2    MFSD2A (2)
# MICAL2    chr11  12200438    MICAL2        up      gene      2    MICAL2 (2)
# NLRP1     chr17   5462746     NLRP1     mixed      gene      2     NLRP1 (2)
# PM20D2     chr6  89865526    PM20D2     mixed      gene      2    PM20D2 (2)
# RFTN1      chr3  16455307     RFTN1     mixed      gene      3     RFTN1 (3)
# SLC46A3   chr13  29283654   SLC46A3        up      gene      2   SLC46A3 (2)
# TNFRSF10D  chr8  23007322 TNFRSF10D     mixed signaling      2 TNFRSF10D (2)
#           meanLogImpact
# CAPG                 NA
# CCDC163P             NA
# CEACAM1           0.996
# CPM                  NA
# DPP4                 NA
# ENPP2                NA
# ESPN                 NA
# FERMT3               NA
# GCH1                 NA
# IL12RB2              NA
# KCNMB4               NA
# KIAA1377             NA
# KLHL6                NA
# MFSD2A               NA
# MICAL2               NA
# NLRP1            -0.579
# PM20D2               NA
# RFTN1                NA
# SLC46A3              NA
# TNFRSF10D            NA
# $targetGenes
#           chr       pos    gene direction  categ frqDEG geneLabel meanLogImpact
# LIPT1    chr2  99775519   LIPT1    target   gene     NA     LIPT1         0.706
# LY75     chr2 160694811    LY75    target   gene     NA      LY75         0.263
# EIF4E3   chr3  71764246  EIF4E3    target   gene     NA    EIF4E3        -1.214
# ZNF518B  chr4  10450266 ZNF518B    target     TF     NA   ZNF518B         0.177
# GGCT     chr7  30563666    GGCT    target cancer     NA      GGCT        -0.970
# CAPZA2   chr7 116506614  CAPZA2    target   gene     NA    CAPZA2         0.192
# ENOX2    chrX 129897279   ENOX2    target   gene     NA     ENOX2        -1.005
# MED21   chr12  27197378   MED21    target     TF     NA     MED21        -1.027
# N6AMT2  chr13  21325484  N6AMT2    target   gene     NA    N6AMT2        -0.979
# CDK8    chr13  26903826    CDK8    target     TF     NA      CDK8        -0.962
# APBA2   chr15  29270074   APBA2    target     TF     NA     APBA2        -1.423
# TNK1    chr17   7288473    TNK1    target   gene     NA      TNK1        -1.174
# KCTD1   chr18  24136120   KCTD1    target   gene     NA     KCTD1        -0.945
# RASSF2  chr20   4782480  RASSF2    target   gene     NA    RASSF2        -0.937
#
# $sourceGenes
#             chr       pos      gene direction     categ frqDEG     geneLabel
# ADORA2A   chr22  24826088   ADORA2A        up      gene      1   ADORA2A (1)
# ARHGEF19   chr1  16531726  ARHGEF19      down      gene      1  ARHGEF19 (1)
# C17orf107 chr17   4804470 C17orf107      down      gene      1 C17orf107 (1)
# C9orf37    chr9 140511571   C9orf37      down      gene      1   C9orf37 (1)
# CHRNE     chr17   4803719     CHRNE      down      gene      1     CHRNE (1)
# CXorf21    chrX  30586451   CXorf21        up      gene      1   CXorf21 (1)
# CYGB      chr17  74535348      CYGB     mixed      gene      2      CYGB (2)
# ELOVL4     chr6  80640913    ELOVL4        up      gene      1    ELOVL4 (1)
# ELOVL6     chr4 111043678    ELOVL6        up      gene      2    ELOVL6 (2)
# FST        chr5  52779602       FST      down signaling      2       FST (2)
# IKZF1      chr7  50408260     IKZF1      down    cancer      1     IKZF1 (1)
# IL32      chr16   3123603      IL32     mixed    cancer      2      IL32 (2)
# ITM2A      chrX  78619522     ITM2A      down      gene      1     ITM2A (1)
# JAM2      chr21  27050729      JAM2      down      gene      1      JAM2 (1)
# LDLRAD2    chr1  22145236   LDLRAD2      down      gene      2   LDLRAD2 (2)
# LY9        chr1 160781958       LY9        up      gene      1       LY9 (1)
# PRKCQ     chr10   6545684     PRKCQ        up      gene      1     PRKCQ (1)
# PSTPIP2   chr18  43607870   PSTPIP2      down      gene      1   PSTPIP2 (1)
# RASGRP2   chr11  64503656   RASGRP2      down signaling      1   RASGRP2 (1)
# TRAF3IP3   chr1 209942522  TRAF3IP3        up      gene      1  TRAF3IP3 (1)
# TRIM14     chr9 100856526    TRIM14      down      gene      1    TRIM14 (1)
# TTC7A      chr2  47223286     TTC7A      down        TF      1     TTC7A (1)
#           meanLogImpact
# ADORA2A              NA
# ARHGEF19             NA
# C17orf107            NA
# C9orf37              NA
# CHRNE                NA
# CXorf21              NA
# CYGB                 NA
# ELOVL4               NA
# ELOVL6               NA
# FST                  NA
# IKZF1                NA
# IL32                 NA
# ITM2A                NA
# JAM2                 NA
# LDLRAD2              NA
# LY9                  NA
# PRKCQ                NA
# PSTPIP2              NA
# RASGRP2              NA
# TRAF3IP3             NA
# TRIM14               NA
# TTC7A                NA
# $targetGenes
#           chr       pos    gene direction categ frqDEG geneLabel meanLogImpact
# SAMD13   chr1  84809844  SAMD13    target  gene     NA    SAMD13        -2.801
# PLB1     chr2  28773333    PLB1    target  gene     NA      PLB1        -3.008
# CELSR3   chr3  48687125  CELSR3    target  gene     NA    CELSR3         0.153
# EIF4E3   chr3  71764246  EIF4E3    target  gene     NA    EIF4E3        -2.315
# LCP2     chr5 169699236    LCP2    target  gene     NA      LCP2        -2.708
# ENPP21   chr8 120627510   ENPP2    target  gene     NA     ENPP2        -2.484
# SUSD1    chr9 114870376   SUSD1    target  gene     NA     SUSD1         0.618
# FERMT31 chr11  63982752  FERMT3    target    TF     NA    FERMT3        -3.814
# EFCAB4B chr12   3794892 EFCAB4B    target  gene     NA   EFCAB4B         0.612
# TC2N    chr14  92289988    TC2N    target  gene     NA      TC2N        -2.699
# SKAP11  chr17  46359220   SKAP1    target  gene     NA     SKAP1        -2.386
# BZRAP1  chr17  56392372  BZRAP1    target  gene     NA    BZRAP1        -2.246
# PES1    chr22  30987841    PES1    target  gene     NA      PES1        -2.266
#
# $sourceGenes
#           chr       pos    gene direction      categ frqDEG   geneLabel
# ENPP2    chr8 120627510   ENPP2      down       gene      2   ENPP2 (2)
# FERMT3  chr11  63982752  FERMT3     mixed         TF      2  FERMT3 (2)
# KLHL6    chr3 183239398   KLHL6     mixed       gene      2   KLHL6 (2)
# LDLRAD2  chr1  22145236 LDLRAD2      down       gene      2 LDLRAD2 (2)
# NLRP1   chr17   5462746   NLRP1      down       gene      2   NLRP1 (2)
# PHGDH    chr1 120244630   PHGDH      down metabolism      2   PHGDH (2)
# RFTN1    chr3  16455307   RFTN1      down       gene      2   RFTN1 (2)
# SKAP1   chr17  46359220   SKAP1      down       gene      2   SKAP1 (2)
# SLC37A1 chr21  43958834 SLC37A1     mixed       gene      2 SLC37A1 (2)
#         meanLogImpact
# ENPP2          -2.484
# FERMT3         -3.814
# KLHL6              NA
# LDLRAD2            NA
# NLRP1              NA
# PHGDH              NA
# RFTN1              NA
# SKAP1          -2.386
# SLC37A1            NA
# png
#   2

# %% [markdown]
# ## export Suppl Table S10: mean impact and expr. ratios per group

# %%
head(geneAnnot)
# Out:
#            chr  V2         chr  V4    V5    V6 V7 V8
# DDX11L1    chr1 pseudogene gene 11869 14412 .  +  .
# WASH7P     chr1 pseudogene gene 14363 29806 .  -  .
# MIR1302-10 chr1 lincRNA    gene 29554 31109 .  +  .
# FAM138A    chr1 lincRNA    gene 34554 36081 .  -  .
# OR4G4P     chr1 pseudogene gene 52473 54936 .  +  .
# OR4G11P    chr1 pseudogene gene 62948 63887 .  +  .
#            V9
# DDX11L1    gene_id ENSG00000223972; gene_name DDX11L1; gene_source ensembl_havana; gene_biotype pseudogene;
# WASH7P     gene_id ENSG00000227232; gene_name WASH7P; gene_source ensembl_havana; gene_biotype pseudogene;
# MIR1302-10 gene_id ENSG00000243485; gene_name MIR1302-10; gene_source ensembl_havana; gene_biotype lincRNA;
# FAM138A    gene_id ENSG00000237613; gene_name FAM138A; gene_source ensembl_havana; gene_biotype lincRNA;
# OR4G4P     gene_id ENSG00000268020; gene_name OR4G4P; gene_source ensembl_havana; gene_biotype pseudogene;
# OR4G11P    gene_id ENSG00000240361; gene_name OR4G11P; gene_source havana; gene_biotype pseudogene;
#            gene       pos
# DDX11L1    DDX11L1    13140
# WASH7P     WASH7P     22084
# MIR1302-10 MIR1302-10 30332
# FAM138A    FAM138A    35318
# OR4G4P     OR4G4P     53704
# OR4G11P    OR4G11P    63418

# %%
exprImpForSave = NULL
for(g in c(targetGenesHigher$gene, targetGenesSlightlyLower$gene, targetGenesLower$gene)) {
    exprImpForSave = rbind(exprImpForSave, data.frame(stringsAsFactors = F, gene = g))
}
exprImpForSave$cluster = c(rep("higher",nrow(targetGenesHigher)), 
                rep("slightly lower",nrow(targetGenesSlightlyLower)),
                rep("lower",nrow(targetGenesLower)))
exprImpForSave$mean_log_impact = c(targetGenesHigher$meanLogImpact, targetGenesSlightlyLower$meanLogImpact, targetGenesLower$meanLogImpact)
exprImpForSave$chr = c(targetGenesHigher$chr, targetGenesSlightlyLower$chr, targetGenesLower$chr)
exprImpForSave = cbind(exprImpForSave,
           geneAnnot[ c(targetGenesHigher$gene, targetGenesSlightlyLower$gene, targetGenesLower$gene),
                         c("V4","V5","V7")])
exprImpForSave = exprImpForSave[,c(1,4:7,2:3)]
colnames(exprImpForSave)[3:5] = c("start","end","strand")
head(exprImpForSave,3)
# Out:
#        gene   chr  start     end       strand cluster mean_log_impact
# RIMS3  RIMS3  chr1  41086351  41131329 -      higher  -0.574
# GLUL   GLUL   chr1 182350839 182361341 -      higher  -0.850
# OCIAD2 OCIAD2 chr4  48887036  48908954 -      higher   1.296

# %%
exprImpForSavePerGroup = list()
for ( sg in names(samplePairPerSubgroup)) {
    sg_nice = samplePairGroupNiceNames[sg]
    # for each sample pair, mean impact from each altered gene on each target gene:
    samplePairGroupMeanLogImp = sapply(samplePairPerSubgroup[[sg]],
                       function(sp) colMeans(logMedianImpRatios[[sp]],na.rm = T))
    impPerSP = 
        samplePairGroupMeanLogImp[ exprImpForSave[ exprImpForSave$cluster == sg_nice,"gene"],]
    exprImpForSavePerGroup[[sg]] = 
        data.frame(exprImpForSave[ exprImpForSave$cluster == sg_nice,],
                   sd_log_impact = apply(impPerSP, 1, sd), 
                  impPerSP)
}

# %%
head(exprImpForSavePerGroup$SG1,3)
# Out:
#        gene   chr  start     end       strand cluster mean_log_impact
# RIMS3  RIMS3  chr1  41086351  41131329 -      higher  -0.574
# GLUL   GLUL   chr1 182350839 182361341 -      higher  -0.850
# OCIAD2 OCIAD2 chr4  48887036  48908954 -      higher   1.296
#        sd_log_impact P04_BSki_1  P08_BSof_2 P16_BLun   P42_BLym_1
# RIMS3  0.4976729     -0.42248151 -0.4950380 -1.2759703 -0.1038084
# GLUL   0.7216468     -0.64380160 -1.9203587 -0.4234703 -0.4115831
# OCIAD2 1.1588276      0.02373786  0.6331459  2.4843909  2.0432249

# %% [markdown]
# ### add expression log-ratios

# %%
# calc expression ratios as in network-propagation-diff-methyl-expr-2021-11-10.r.ipynb 
voomExpr = read.csv(file = "regNet/Data/MelBrainSys-expression.csv", header = T, sep = "\t", stringsAsFactors = F)
#head(voomExpr[,-c(1:3)],4)
quantile(as.matrix(voomExpr[,-c(1:3)])) # 
# calc log-ratios for each sample pair:
all(unlist(sampleMapping) %in% colnames(voomExpr))
voomExprRatios = sapply(sampleMapping, function(pair) voomExpr[,pair[1]]-voomExpr[,pair[2]])
rownames(voomExprRatios) = voomExpr$geneSymbol
head(voomExprRatios,3)
# Out:
#        0%       25%       50%       75%      100%
# -7.954093  3.280165  4.872348  6.223607 13.556041
# [1] TRUE
#        P03_BLun   P04_BSki_1 P08_BSof_1  P08_BSof_2 P08_BSof_3 P16_BLun
# NOC2L  -0.1520841 -0.1527628 -0.07196192 0.04843198 0.12919549 -0.2051571
# KLHL17 -0.4640437 -0.4452138 -0.62484913 0.21396964 0.07035122 -2.0311541
# HES4    1.2257478 -0.2795358  1.51776997 2.69686809 0.14448191  3.6441262
#        P18_BLun_1 P18_BLun_2 P39_BLun    P42_BLym_1 P42_BLym_2
# NOC2L  -0.5292115 -0.4299746  0.02099164  0.1372947  0.7571580
# KLHL17 -0.8454868 -1.8212825 -0.51625349 -0.7036537  0.6215336
# HES4   -0.5422570  1.2603740 -1.09090370  1.0655378 -1.6381859

# %%
for ( sg in names(samplePairPerSubgroup)) {
    genes = exprImpForSavePerGroup[[sg]]$gene
    groupVoomExpr =  voomExprRatios[genes,samplePairPerSubgroup[[sg]]]
    groupVoomExprMean = rowMeans(voomExprRatios[genes,samplePairPerSubgroup[[sg]]])
    groupVoomExprSD = apply(voomExprRatios[genes,samplePairPerSubgroup[[sg]]],1,sd)
    exprImpForSavePerGroup[[sg]] = 
        data.frame(exprImpForSavePerGroup[[sg]], 
                   mean_log_expression = groupVoomExprMean, sd_log_expression = groupVoomExprSD,
                  groupVoomExpr)
    # remove .1 .2 .. from sample names
    colnames(exprImpForSavePerGroup[[sg]]) = gsub("\\.\\d+$","",colnames(exprImpForSavePerGroup[[sg]]))
}

# %%
exprImpForSavePerGroup$SG1
# Out:
#          gene     chr   start     end       strand cluster mean_log_impact
# RIMS3    RIMS3    chr1   41086351  41131329 -      higher  -0.574
# GLUL     GLUL     chr1  182350839 182361341 -      higher  -0.850
# OCIAD2   OCIAD2   chr4   48887036  48908954 -      higher   1.296
# NCOA7    NCOA7    chr6  126102307 126252266 +      higher  -1.284
# PPIA     PPIA     chr7   44836279  44864163 +      higher  -0.480
# SORBS3   SORBS3   chr8   22402499  22433301 +      higher   1.072
# GADD45G  GADD45G  chr9   92219928  92221470 +      higher  -0.715
# FBP1     FBP1     chr9   97365415  97402531 -      higher  -0.800
# RNH1     RNH1     chr11    494512    507300 -      higher   2.491
# ARHGEF17 ARHGEF17 chr11  73019334  73080136 +      higher   1.045
# RB1      RB1      chr13  48877887  49056122 +      higher   1.115
# SMAD3    SMAD3    chr15  67356101  67487533 +      higher   1.016
# CBFA2T3  CBFA2T3  chr16  88941266  89043612 -      higher  -0.671
# NLRP1    NLRP1    chr17   5402747   5522744 -      higher  -0.579
# TRIM47   TRIM47   chr17  73870242  73874656 -      higher   0.994
# PIAS2    PIAS2    chr18  44388353  44500123 -      higher   1.643
# CNDP2    CNDP2    chr18  72163051  72188366 +      higher  -0.512
# HCST     HCST     chr19  36393382  36395279 +      higher  -0.809
# CEACAM1  CEACAM1  chr19  43011456  43065386 -      higher   0.996
# ZNF225   ZNF225   chr19  44616334  44637027 +      higher   1.990
#          sd_log_impact P04_BSki_1  P08_BSof_2 P16_BLun    P42_BLym_1
# RIMS3    0.4976729     -0.42248151 -0.4950380 -1.27597035 -0.103808370
# GLUL     0.7216468     -0.64380160 -1.9203587 -0.42347029 -0.411583105
# OCIAD2   1.1588276      0.02373786  0.6331459  2.48439091  2.043224856
# NCOA7    0.6086524     -1.54944015 -1.9107861 -1.18995123 -0.484494429
# PPIA     0.8247846     -0.17238477 -1.7117092 -0.03065235 -0.003385268
# SORBS3   1.5234907      0.40296951  0.3628040  0.16901120  3.351719913
# GADD45G  0.5270849     -0.39243095 -1.4877529 -0.36619903 -0.612062732
# FBP1     0.4490635     -1.08567626 -1.2224519 -0.22868138 -0.664011978
# RNH1     2.4238485      0.22762359  3.3287446  5.52536272  0.880695925
# ARHGEF17 0.6166144      0.88100052  1.9468820  0.79784928  0.555847672
# RB1      0.6901705      0.67183320  0.3923680  1.57843872  1.819015285
# SMAD3    0.7151082      0.66284299  0.9392841  0.42114669  2.040540614
# CBFA2T3  0.6625642     -1.17080364 -1.3143963 -0.11937267 -0.080306465
# NLRP1    0.4701011     -0.29372176 -1.1302170 -0.09738463 -0.793029550
# TRIM47   0.6183288      1.17947950  0.6230914  1.77788282  0.393546328
# PIAS2    1.6007777      1.80260080  3.7797692  0.97693330  0.014329418
# CNDP2    0.2841297     -0.60080098 -0.7730289 -0.10815054 -0.567438419
# HCST     0.7099634     -0.59319905 -1.8634061 -0.41253813 -0.365581449
# CEACAM1  0.6296047      1.20348171  0.2264258  0.83333209  1.722259499
# ZNF225   1.1907106      0.93228179  1.6027803  3.69758546  1.727664124
#          mean_log_expression sd_log_expression P04_BSki_1 P08_BSof_2 P16_BLun
# RIMS3     0.17612144         3.5592713          0.1283620 -3.3397539  5.0637261
# GLUL      1.09179665         2.4052011          0.8418873 -1.2610172  0.3474669
# OCIAD2    1.14106673         3.3148104         -2.8595384  1.3530239  0.8288992
# NCOA7    -0.28429887         1.1515803         -1.6834161  0.3771632 -0.7251882
# PPIA     -0.17885589         0.3763027         -0.4164953  0.3761208 -0.2668562
# SORBS3   -0.03144900         0.8263931          0.4196819  0.7099890 -1.1682966
# GADD45G  -0.40207213         0.9376352          0.4202563 -1.3910209 -1.0149495
# FBP1      0.78261572         0.8304746          0.2541783 -0.1045086  1.4689362
# RNH1      0.09588491         0.8658106         -0.4712348  0.9171057 -0.8123738
# ARHGEF17  0.03150624         0.4639899          0.2373885 -0.6605284  0.3310994
# RB1      -0.04610982         0.4973091          0.2228810 -0.6423775  0.4784322
# SMAD3    -0.33832555         0.5221266          0.4100029 -0.5772376 -0.7814769
# CBFA2T3  -1.46545940         4.5388321          0.5323240 -0.7568223 -7.9978264
# NLRP1    -0.10363244         2.1935940         -1.4155680 -2.0314702  0.1469907
# TRIM47    0.81178817         0.9494743          0.1742025  0.5383951  0.3164085
# PIAS2    -0.25193515         0.6128100          0.2979506 -1.0200471  0.1815440
# CNDP2     0.07320137         0.6996962          0.5065156 -0.8237516 -0.1244894
# HCST      0.73854293         2.1347452         -0.8091478  0.6502336 -0.6716870
# CEACAM1   0.15505592         2.1570421         -1.9026219 -1.4848772  1.6884961
# ZNF225    0.61924823         0.6772981          1.3877468  0.5612300  0.7787170
#          P42_BLym_1
# RIMS3    -1.14784841
# GLUL      4.43884956
# OCIAD2    5.24188223
# NCOA7     0.89424568
# PPIA     -0.40819283
# SORBS3   -0.08717032
# GADD45G   0.37742553
# FBP1      1.51185706
# RNH1      0.75004246
# ARHGEF17  0.21806548
# RB1      -0.24337501
# SMAD3    -0.40459066
# CBFA2T3   2.36048715
# NLRP1     2.88551774
# TRIM47    2.21814663
# PIAS2    -0.46718802
# CNDP2     0.73453088
# HCST      3.78477299
# CEACAM1   2.31922665
# ZNF225   -0.25070091

# %%
write.xlsx(exprImpForSavePerGroup$SG1, 
           file = paste0(outDirectory,"SupplTable-S10-target-gene-candidates.xls"),
           sheetName = "higher cluster", append = F, row.names = F)
write.xlsx(exprImpForSavePerGroup$SG3, 
           file = paste0(outDirectory,"SupplTable-S10-target-gene-candidates.xls"),
           sheetName = "sligthly lower cluster", append = T, row.names = F)
write.xlsx(exprImpForSavePerGroup$SG2, 
           file = paste0(outDirectory,"SupplTable-S10-target-gene-candidates.xls"),
           sheetName = "lower cluster", append = T, row.names = F)

# %% [markdown]
# ## SupplFigure S6: scatter plot of target genes

# %%
neededCols = c("gene","chr","start","end","strand","cluster","mean_log_impact","mean_log_expression")
exprImpForPlot = rbind(exprImpForSavePerGroup$SG1[,neededCols],
                      exprImpForSavePerGroup$SG3[,neededCols],
                      exprImpForSavePerGroup$SG2[,neededCols])
colnames(exprImpForPlot)[6] = "subgroup"
exprImpForPlot$subgroup = ifelse(exprImpForPlot$subgroup=="higher","SG1",
                                 ifelse(exprImpForPlot$subgroup=="lower","SG2","SG3"))

# %%
head(exprImpForPlot,3)
tail(exprImpForPlot,3)
# Out:
#        gene   chr  start     end       strand subgroup mean_log_impact
# RIMS3  RIMS3  chr1  41086351  41131329 -      SG1      -0.574
# GLUL   GLUL   chr1 182350839 182361341 -      SG1      -0.850
# OCIAD2 OCIAD2 chr4  48887036  48908954 -      SG1       1.296
#        mean_log_expression
# RIMS3  0.1761214
# GLUL   1.0917966
# OCIAD2 1.1410667
#        gene   chr   start    end      strand subgroup mean_log_impact
# SKAP1  SKAP1  chr17 46210802 46507637 -      SG2      -2.386
# BZRAP1 BZRAP1 chr17 56378592 56406152 -      SG2      -2.246
# PES1   PES1   chr22 30972612 31003070 -      SG2      -2.266
#        mean_log_expression
# SKAP1  -2.0078000
# BZRAP1 -1.2304650
# PES1    0.4500281

# %%
exprImpForPlot
# Out:
#          gene     chr   start     end       strand subgroup mean_log_impact
# RIMS3    RIMS3    chr1   41086351  41131329 -      SG1      -0.574
# GLUL     GLUL     chr1  182350839 182361341 -      SG1      -0.850
# OCIAD2   OCIAD2   chr4   48887036  48908954 -      SG1       1.296
# NCOA7    NCOA7    chr6  126102307 126252266 +      SG1      -1.284
# PPIA     PPIA     chr7   44836279  44864163 +      SG1      -0.480
# SORBS3   SORBS3   chr8   22402499  22433301 +      SG1       1.072
# GADD45G  GADD45G  chr9   92219928  92221470 +      SG1      -0.715
# FBP1     FBP1     chr9   97365415  97402531 -      SG1      -0.800
# RNH1     RNH1     chr11    494512    507300 -      SG1       2.491
# ARHGEF17 ARHGEF17 chr11  73019334  73080136 +      SG1       1.045
# RB1      RB1      chr13  48877887  49056122 +      SG1       1.115
# SMAD3    SMAD3    chr15  67356101  67487533 +      SG1       1.016
# CBFA2T3  CBFA2T3  chr16  88941266  89043612 -      SG1      -0.671
# NLRP1    NLRP1    chr17   5402747   5522744 -      SG1      -0.579
# TRIM47   TRIM47   chr17  73870242  73874656 -      SG1       0.994
# PIAS2    PIAS2    chr18  44388353  44500123 -      SG1       1.643
# CNDP2    CNDP2    chr18  72163051  72188366 +      SG1      -0.512
# HCST     HCST     chr19  36393382  36395279 +      SG1      -0.809
# CEACAM1  CEACAM1  chr19  43011456  43065386 -      SG1       0.996
# ZNF225   ZNF225   chr19  44616334  44637027 +      SG1       1.990
# LIPT1    LIPT1    chr2   99771418  99779620 +      SG3       0.706
# LY75     LY75     chr2  160628362 160761260 -      SG3       0.263
# EIF4E3   EIF4E3   chr3   71724567  71803924 -      SG3      -1.214
# ZNF518B  ZNF518B  chr4   10441498  10459034 -      SG3       0.177
# GGCT     GGCT     chr7   30536237  30591095 -      SG3      -0.970
# CAPZA2   CAPZA2   chr7  116451124 116562103 +      SG3       0.192
# ENOX2    ENOX2    chrX  129757350 130037208 -      SG3      -1.005
# MED21    MED21    chr12  27175479  27219276 +      SG3      -1.027
# N6AMT2   N6AMT2   chr13  21302870  21348097 -      SG3      -0.979
# CDK8     CDK8     chr13  26828276  26979375 +      SG3      -0.962
# APBA2    APBA2    chr15  29129629  29410518 +      SG3      -1.423
# TNK1     TNK1     chr17   7283853   7293093 +      SG3      -1.174
# KCTD1    KCTD1    chr18  24034874  24237365 -      SG3      -0.945
# RASSF2   RASSF2   chr20   4760669   4804291 -      SG3      -0.937
# SAMD13   SAMD13   chr1   84764049  84855640 +      SG2      -2.801
# PLB1     PLB1     chr2   28680012  28866654 +      SG2      -3.008
# CELSR3   CELSR3   chr3   48673902  48700348 -      SG2       0.153
# EIF4E3.1 EIF4E3   chr3   71724567  71803924 -      SG2      -2.315
# LCP2     LCP2     chr5  169673241 169725231 -      SG2      -2.708
# ENPP2    ENPP2    chr8  120569326 120685693 -      SG2      -2.484
# SUSD1    SUSD1    chr9  114803065 114937688 -      SG2       0.618
# FERMT3   FERMT3   chr11  63974150  63991354 +      SG2      -3.814
# EFCAB4B  EFCAB4B  chr12   3715799   3873985 -      SG2       0.612
# TC2N     TC2N     chr14  92246095  92333880 -      SG2      -2.699
# SKAP1    SKAP1    chr17  46210802  46507637 -      SG2      -2.386
# BZRAP1   BZRAP1   chr17  56378592  56406152 -      SG2      -2.246
# PES1     PES1     chr22  30972612  31003070 -      SG2      -2.266
#          mean_log_expression
# RIMS3     0.17612144
# GLUL      1.09179665
# OCIAD2    1.14106673
# NCOA7    -0.28429887
# PPIA     -0.17885589
# SORBS3   -0.03144900
# GADD45G  -0.40207213
# FBP1      0.78261572
# RNH1      0.09588491
# ARHGEF17  0.03150624
# RB1      -0.04610982
# SMAD3    -0.33832555
# CBFA2T3  -1.46545940
# NLRP1    -0.10363244
# TRIM47    0.81178817
# PIAS2    -0.25193515
# CNDP2     0.07320137
# HCST      0.73854293
# CEACAM1   0.15505592
# ZNF225    0.61924823
# LIPT1    -0.18730360
# LY75      0.21494643
# EIF4E3    0.03127001
# ZNF518B  -0.26269479
# GGCT      0.29334190
# CAPZA2    0.02926538
# ENOX2    -0.03417450
# MED21     0.41192875
# N6AMT2    0.40148199
# CDK8     -0.04598672
# APBA2    -0.47629280
# TNK1     -1.91214231
# KCTD1    -0.28140530
# RASSF2    0.88758902
# SAMD13    0.08715356
# PLB1     -0.40047570
# CELSR3   -0.30303496
# EIF4E3.1 -0.86028164
# LCP2     -0.10351863
# ENPP2    -1.29198084
# SUSD1    -0.04181413
# FERMT3    0.08542984
# EFCAB4B   0.18403684
# TC2N     -3.05581633
# SKAP1    -2.00780000
# BZRAP1   -1.23046498
# PES1      0.45002808

# %%
# get middle of cluster group impact ratios to draw intersection lines
o = order(exprImpForPlot$mean_log_impact)
cbind(exprImpForPlot$mean_log_impact[o],exprImpForPlot$subgroup[o])
intersect1 = mean(exprImpForPlot$mean_log_impact[o][c(10:11)])
intersect2 = mean(exprImpForPlot$mean_log_impact[o][c(21:22)])
intersect1
intersect2
# Out:
#       [,1]   [,2]
#  [1,] -3.814 SG2
#  [2,] -3.008 SG2
#  [3,] -2.801 SG2
#  [4,] -2.708 SG2
#  [5,] -2.699 SG2
#  [6,] -2.484 SG2
#  [7,] -2.386 SG2
#  [8,] -2.315 SG2
#  [9,] -2.266 SG2
# [10,] -2.246 SG2
# [11,] -1.423 SG3
# [12,] -1.284 SG1
# [13,] -1.214 SG3
# [14,] -1.174 SG3
# [15,] -1.027 SG3
# [16,] -1.005 SG3
# [17,] -0.979 SG3
# [18,] -0.97  SG3
# [19,] -0.962 SG3
# [20,] -0.945 SG3
# [21,] -0.937 SG3
# [22,] -0.85  SG1
# [23,] -0.809 SG1
# [24,] -0.8   SG1
# [25,] -0.715 SG1
# [26,] -0.671 SG1
# [27,] -0.579 SG1
# [28,] -0.574 SG1
# [29,] -0.512 SG1
# [30,] -0.48  SG1
# [31,] 0.153  SG2
# [32,] 0.177  SG3
# [33,] 0.192  SG3
# [34,] 0.263  SG3
# [35,] 0.612  SG2
# [36,] 0.618  SG2
# [37,] 0.706  SG3
# [38,] 0.994  SG1
# [39,] 0.996  SG1
# [40,] 1.016  SG1
# [41,] 1.045  SG1
# [42,] 1.072  SG1
# [43,] 1.115  SG1
# [44,] 1.296  SG1
# [45,] 1.643  SG1
# [46,] 1.99   SG1
# [47,] 2.491  SG1
# [1] -1.8345
# [1] -0.8935

# %%
p = ggplot(data = exprImpForPlot, mapping = aes(x = mean_log_impact, y = mean_log_expression, 
                                                col=subgroup)) + #, label=gene)) + 
    geom_vline(xintercept = intersect1, col="grey") + geom_vline(xintercept = intersect2, col="grey") + 
    geom_smooth(method='lm', col="darkgrey",mapping = aes(x = mean_log_impact, y = mean_log_expression, group=1) ) +
    geom_point(size=1) + 
    geom_text_repel(hjust=-0.1, size=2, col="#222222", segment.colour="darkgrey", fontface="italic", 
                    mapping = aes(label=gene)) + 
    scale_color_manual(values = annotColors$subgroup) + 
        xlab(expression(impact~log["2"]~ratio)) + ylab(expression(expression~log["2"]~ratio))
   # annotate(geom = "text",x = -1.5, y = 2, label=paste0("p = ",round(testRes$p.value,3),", R = ",round(testRes$estimate,2)))
p
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
png(filename = paste0(outDirectory,"SupplFigure-S6-target-gene-candidates-scatterplot.png"),
    width = 1600,height = 1200, res=300)
p
dev.off()
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# png
#   2
